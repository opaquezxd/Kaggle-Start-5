# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load in 

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
from sklearn.model_selection import KFold, StratifiedKFold
from sklearn.metrics import roc_auc_score
import lightgbm as lgb
import xgboost as xgb
from catboost import CatBoostClassifier
from bayes_opt import BayesianOptimization

import gc

# Input data files are available in the "../input/" directory.
# For example, running this (by clicking run or pressing Shift+Enter) will list the files in the input directory

import os
print(os.listdir("../input"))

# Any results you write to the current directory are saved as output.
# Out:
# ['sample_submission.csv', 'test.csv', 'train.csv']

# %%
train_data = pd.read_csv('../input/train.csv')
test_data = pd.read_csv('../input/test.csv')

# %%
raws_features = train_data.columns[2:]
train_X, train_y = train_data[raws_features], train_data['target']
test_X = test_data[raws_features]

# %%
n_splits = 10
num_round = 77777
seed = 7777

# %% [markdown]
# Creating classes fo CV to automate the process

# %%
class CVClassifier():
    def __init__(self, estimator, n_splits=5, stratified=True, num_round=77777, **params):
        self.n_splits_ = n_splits
        self.scores_ = []
        self.clf_list_ = []
        self.estimator_ = estimator
        self.stratified_ = stratified
        self.num_round_ = num_round
        if params:
            self.params_ = params
        
    def cv(self, train_X, train_y):
        if self.stratified_:
            folds = StratifiedKFold(self.n_splits_, shuffle=True, random_state=seed)
        else:
            folds = KFold(self.n_splits_, shuffle=True, random_state=seed)
        oof = np.zeros(len(train_y))
        for fold, (train_idx, val_idx) in enumerate(folds.split(train_X, train_y)):
            print('fold %d' % fold)
            trn_data, trn_y = train_X.iloc[train_idx], train_y[train_idx]
            val_data, val_y = train_X.iloc[val_idx], train_y[val_idx]
            if self.estimator_ == 'lgbm':
                train_set = lgb.Dataset(data=trn_data, label=trn_y)
                val_set = lgb.Dataset(data=val_data, label=val_y)
                clf = lgb.train(params=params, train_set=train_set, num_boost_round=num_round, 
                                valid_sets=[train_set, val_set], verbose_eval=100, early_stopping_rounds=200)
                oof[val_idx] = clf.predict(train_X.iloc[val_idx], num_iteration=clf.best_iteration)
                
            elif self.estimator_ == 'xgb':
                train_set = xgb.DMatrix(data=trn_data, label=trn_y)
                val_set = xgb.DMatrix(data=val_data, label=val_y)
                watchlist = [(train_set, 'train'), (val_set, 'valid')]
                clf = xgb.train(self.params_, train_set, self.num_round_, watchlist, 
                               early_stopping_rounds=200, verbose_eval=100)
                oof[val_idx] = clf.predict(val_set, ntree_limit=clf.best_ntree_limit)
            
            elif self.estimator_ == 'cat':
                clf = CatBoostClassifier(self.num_round_, task_type='GPU', early_stopping_rounds=500, **self.params_)
                clf.fit(trn_data, trn_y, eval_set=(val_data, val_y), cat_features=[], use_best_model=True, verbose=500)
                oof[val_idx] = clf.predict_proba(val_data)[:, 1]

            # sk-learn model
            else:
                clf = self.estimator_.fit(trn_data, trn_y)
                try:
                    oof[val_idx] = clf.predict_proba(val_data)[:, 1]
                except AttributeError:
                    oof[val_idx] = clf.decision_function(val_data)
            
            self.clf_list_.append(clf)
            fold_score = roc_auc_score(train_y[val_idx], oof[val_idx])
            self.scores_.append(fold_score)
            print('Fold score: {:<8.5f}'.format(fold_score))
        self.oof_ = oof
        self.score_ = roc_auc_score(train_y, oof)
        print("CV score: {:<8.5f}".format(self.score_))
        
    def predict(self, test_X):
        self.predictions_ = np.zeros(len(test_X))
        
        if self.estimator_ == 'lgbm':
            self.feature_importance_df_ = pd.DataFrame()
            for fold, clf in enumerate(self.clf_list_):
                fold_importance_df = pd.DataFrame()
                fold_importance_df["feature"] = features
                fold_importance_df["importance"] = clf.feature_importance()
                fold_importance_df["fold"] = fold + 1
                self.feature_importance_df_ = pd.concat([self.feature_importance_df_, fold_importance_df], axis=0)
                
                self.predictions_ += clf.predict(test_X, num_iteration=clf.best_iteration) * (self.scores_[fold] / sum(self.scores_))
        elif self.estimator_ == 'xgb':
            for fold, clf in enumerate(self.clf_list_):
                self.predictions_ += clf.predict(xgb.DMatrix(test_X), ntree_limit=clf.best_ntree_limit) \
                * (self.scores_[fold] / sum(self.scores_))
        elif self.estimator_ == 'cat':
            for fold, clf in enumerate(self.clf_list_):
                self.predictions_ += clf.predict_proba(test_X)[:, 1] * (self.scores_[fold] / sum(self.scores_))
        else:
            for fold, clf in enumerate(self.clf_list_):
                self.predictions_ += clf.predict_proba(test_X)[:, 1] * (self.scores_[fold] / sum(self.scores_))

# %%
# Class for Bayesian Optimisation
class CVForBO():
    def __init__(self, model, train_X, train_y, test_X, base_params, int_params=[], n_splits=5, num_round=77777):
        self.oofs_ = []
        self.params_ = []
        self.predictions_ = []
        self.cv_scores_ = []
        self.model_ = model
        self.train_X_ = train_X
        self.train_y_ = train_y
        self.test_X_ = test_X
        self.base_params_ = base_params
        self.int_params_ = int_params
        self.n_splits_ = n_splits
        self.num_round_ = num_round
        
    def cv(self, **opt_params):
        for p in self.int_params_:
            if p in opt_params:
                opt_params[p] = int(np.round(opt_params[p]))
        self.base_params_.update(opt_params)
        
        cv_model = CVClassifier(self.model_, n_splits=self.n_splits_, num_round=self.num_round_, **self.base_params_)
        cv_model.cv(self.train_X_, self.train_y_)
        cv_model.predict(self.test_X_)
        
        self.oofs_.append(cv_model.oof_)
        self.predictions_.append(cv_model.predictions_)
        self.params_.append(self.base_params_)
        self.cv_scores_.append(cv_model.score_)

        return cv_model.score_
    
    def post_process(self, model_type=None, oof_path='inter_oofs.csv', pred_path='inter_preds.csv', params_path='inter_params.csv'):
        if not model_type:
            model_type=self.model_
        cols = ['{}_{}_{}'.format(model_type, str(self.cv_scores_[k]).split('.')[-1][:5], k) for k in range(len(self.cv_scores_))]
        self.oof_df = pd.DataFrame(np.array(self.oofs_).T, columns=cols)
        self.pred_df = pd.DataFrame(np.array(self.predictions_).T, columns=cols)
        self.params_df = pd.DataFrame(self.params_).T.rename(columns={c_old: c_new for c_old, c_new in enumerate(cols)})
        
        self.oof_df.to_csv(oof_path)
        self.pred_df.to_csv(pred_path)
        self.params_df.to_csv(params_path)

# %%
cat_params = {
    'eval_metric': 'AUC',
    'bootstrap_type': 'Bernoulli',
    'objective': 'Logloss',
    'od_type': 'Iter',
    'random_seed': seed,
    'allow_writing_files': False}

cv_cat_for_BO = CVForBO('cat', train_X, train_y, test_X, cat_params, ['depth'])
cat_BO = BayesianOptimization(cv_cat_for_BO.cv, {
    'depth': (2, 4), 
    'l2_leaf_reg': (37, 97), 
    'random_strength': (5, 17), 
    'eta': (0.01, 0.1)
    }, random_state=seed)

cat_BO.maximize(init_points=2, n_iter=15, acq='ei')
# Out:
# |   iter    |  target   |   depth   |    eta    | l2_lea... | random... |
# -------------------------------------------------------------------------
# fold 0
# 0:	learn: 0.5876077	test: 0.5794046	best: 0.5794046 (0)	total: 27ms	remaining: 35m 3s
# 500:	learn: 0.8948264	test: 0.8852875	best: 0.8852875 (500)	total: 11.5s	remaining: 29m 39s
# 1000:	learn: 0.9127659	test: 0.8968543	best: 0.8968543 (1000)	total: 22.8s	remaining: 29m 9s
# 1500:	learn: 0.9222238	test: 0.8998253	best: 0.8998253 (1500)	total: 33.3s	remaining: 28m 13s
# 2000:	learn: 0.9297802	test: 0.9013476	best: 0.9013621 (1990)	total: 43.6s	remaining: 27m 33s
# 2500:	learn: 0.9361933	test: 0.9015219	best: 0.9015345 (2497)	total: 54.1s	remaining: 27m 7s
# 3000:	learn: 0.9420816	test: 0.9018041	best: 0.9018357 (2982)	total: 1m 4s	remaining: 26m 39s
# 3500:	learn: 0.9474182	test: 0.9018416	best: 0.9018758 (3474)	total: 1m 14s	remaining: 26m 14s
# 4000:	learn: 0.9525000	test: 0.9018716	best: 0.9019774 (3680)	total: 1m 24s	remaining: 25m 57s
# bestTest = 0.9019773602
# bestIteration = 3680
# Shrink model to first 3681 iterations.
# Fold score: 0.90198
# fold 1
# 0:	learn: 0.5767654	test: 0.5637967	best: 0.5637967 (0)	total: 24.3ms	remaining: 31m 31s
# 500:	learn: 0.8951066	test: 0.8860088	best: 0.8860088 (500)	total: 10.6s	remaining: 27m 10s
# 1000:	learn: 0.9126751	test: 0.8970411	best: 0.8970461 (999)	total: 21.2s	remaining: 27m 2s
# 1500:	learn: 0.9223152	test: 0.9009182	best: 0.9009249 (1499)	total: 31.7s	remaining: 26m 52s
# 2000:	learn: 0.9297766	test: 0.9019081	best: 0.9019789 (1944)	total: 42s	remaining: 26m 32s
# 2500:	learn: 0.9363792	test: 0.9022921	best: 0.9023636 (2471)	total: 52.3s	remaining: 26m 13s
# 3000:	learn: 0.9423154	test: 0.9024035	best: 0.9025029 (2880)	total: 1m 2s	remaining: 26m 1s
# 3500:	learn: 0.9478861	test: 0.9024694	best: 0.9026920 (3340)	total: 1m 13s	remaining: 25m 52s
# bestTest = 0.9026920199
# bestIteration = 3340
# Shrink model to first 3341 iterations.
# Fold score: 0.90269
# fold 2
# 0:	learn: 0.5831620	test: 0.5872198	best: 0.5872198 (0)	total: 26.4ms	remaining: 34m 14s
# 500:	learn: 0.8957095	test: 0.8793032	best: 0.8793189 (499)	total: 11.7s	remaining: 29m 57s
# 1000:	learn: 0.9136022	test: 0.8912323	best: 0.8912323 (1000)	total: 23s	remaining: 29m 21s
# 1500:	learn: 0.9231651	test: 0.8941430	best: 0.8941516 (1499)	total: 34.3s	remaining: 29m 1s
# 2000:	learn: 0.9306341	test: 0.8952925	best: 0.8953199 (1994)	total: 45s	remaining: 28m 24s
# 2500:	learn: 0.9369730	test: 0.8957484	best: 0.8957940 (2427)	total: 55.4s	remaining: 27m 46s
# bestTest = 0.895794034
# bestIteration = 2427
# Shrink model to first 2428 iterations.
# Fold score: 0.89579
# fold 3
# 0:	learn: 0.5887079	test: 0.5904347	best: 0.5904347 (0)	total: 27.1ms	remaining: 35m 9s
# 500:	learn: 0.8958996	test: 0.8808566	best: 0.8808566 (500)	total: 11.7s	remaining: 30m 8s
# 1000:	learn: 0.9138399	test: 0.8912673	best: 0.8912673 (1000)	total: 23s	remaining: 29m 25s
# 1500:	learn: 0.9236532	test: 0.8938972	best: 0.8939008 (1499)	total: 33.3s	remaining: 28m 11s
# 2000:	learn: 0.9311427	test: 0.8947960	best: 0.8948264 (1983)	total: 43.3s	remaining: 27m 18s
# 2500:	learn: 0.9374835	test: 0.8951964	best: 0.8952421 (2408)	total: 53.2s	remaining: 26m 42s
# bestTest = 0.895242095
# bestIteration = 2408
# Shrink model to first 2409 iterations.
# Fold score: 0.89524
# fold 4
# 0:	learn: 0.5880826	test: 0.5912256	best: 0.5912256 (0)	total: 25.3ms	remaining: 32m 46s
# 500:	learn: 0.8961504	test: 0.8802696	best: 0.8802696 (500)	total: 10.7s	remaining: 27m 35s
# 1000:	learn: 0.9135668	test: 0.8916662	best: 0.8916662 (1000)	total: 21.1s	remaining: 26m 54s
# 1500:	learn: 0.9233961	test: 0.8948449	best: 0.8948692 (1494)	total: 31.2s	remaining: 26m 25s
# 2000:	learn: 0.9308790	test: 0.8958026	best: 0.8958253 (1903)	total: 41.3s	remaining: 26m 5s
# 2500:	learn: 0.9372119	test: 0.8960468	best: 0.8961043 (2466)	total: 51.6s	remaining: 25m 52s
# 3000:	learn: 0.9429314	test: 0.8960166	best: 0.8961529 (2604)	total: 1m 1s	remaining: 25m 43s
# bestTest = 0.8961528838
# bestIteration = 2604
# Shrink model to first 2605 iterations.
# Fold score: 0.89615
# CV score: 0.89839
# |  1        |  0.8984   |  3.623    |  0.07231  |  64.15    |  16.96    |
# fold 0
# 0:	learn: 0.5898380	test: 0.5816775	best: 0.5816775 (0)	total: 30.2ms	remaining: 39m 8s
# 500:	learn: 0.8722334	test: 0.8653554	best: 0.8653554 (500)	total: 11.5s	remaining: 29m 35s
# 1000:	learn: 0.8945991	test: 0.8849061	best: 0.8849061 (1000)	total: 22.2s	remaining: 28m 22s
# 1500:	learn: 0.9054769	test: 0.8928452	best: 0.8928452 (1500)	total: 32.4s	remaining: 27m 26s
# 2000:	learn: 0.9125918	test: 0.8967928	best: 0.8967965 (1999)	total: 42.8s	remaining: 27m 1s
# 2500:	learn: 0.9180138	test: 0.8989067	best: 0.8989131 (2495)	total: 53.1s	remaining: 26m 37s
# 3000:	learn: 0.9224564	test: 0.9002969	best: 0.9002969 (3000)	total: 1m 3s	remaining: 26m 11s
# 3500:	learn: 0.9263526	test: 0.9010165	best: 0.9010206 (3497)	total: 1m 13s	remaining: 25m 52s
# 4000:	learn: 0.9298248	test: 0.9015435	best: 0.9015435 (4000)	total: 1m 23s	remaining: 25m 36s
# 4500:	learn: 0.9331642	test: 0.9018920	best: 0.9018978 (4465)	total: 1m 33s	remaining: 25m 23s
# 5000:	learn: 0.9362072	test: 0.9020407	best: 0.9020407 (5000)	total: 1m 43s	remaining: 25m 7s
# 5500:	learn: 0.9392112	test: 0.9022118	best: 0.9022143 (5495)	total: 1m 53s	remaining: 24m 51s
# 6000:	learn: 0.9419484	test: 0.9023202	best: 0.9023759 (5945)	total: 2m 3s	remaining: 24m 38s
# 6500:	learn: 0.9446709	test: 0.9024428	best: 0.9024428 (6500)	total: 2m 13s	remaining: 24m 29s
# 7000:	learn: 0.9472928	test: 0.9024917	best: 0.9025153 (6919)	total: 2m 24s	remaining: 24m 18s
# bestTest = 0.902515322
# bestIteration = 6919
# Shrink model to first 6920 iterations.
# Fold score: 0.90252
# fold 1
# 0:	learn: 0.5767654	test: 0.5637967	best: 0.5637967 (0)	total: 25.9ms	remaining: 33m 32s
# 500:	learn: 0.8711625	test: 0.8655222	best: 0.8655222 (500)	total: 11.7s	remaining: 30m 4s
# 1000:	learn: 0.8945138	test: 0.8858723	best: 0.8858723 (1000)	total: 22.9s	remaining: 29m 13s
# 1500:	learn: 0.9055462	test: 0.8933941	best: 0.8934015 (1498)	total: 34.1s	remaining: 28m 51s
# 2000:	learn: 0.9127321	test: 0.8974312	best: 0.8974444 (1999)	total: 45.3s	remaining: 28m 34s
# 2500:	learn: 0.9179865	test: 0.8994946	best: 0.8994981 (2499)	total: 56.5s	remaining: 28m 19s
# 3000:	learn: 0.9224390	test: 0.9008445	best: 0.9008445 (3000)	total: 1m 7s	remaining: 28m 4s
# 3500:	learn: 0.9262924	test: 0.9017946	best: 0.9017956 (3499)	total: 1m 18s	remaining: 27m 51s
# 4000:	learn: 0.9298536	test: 0.9022976	best: 0.9022976 (4000)	total: 1m 29s	remaining: 27m 26s
# 4500:	learn: 0.9331996	test: 0.9025916	best: 0.9026176 (4473)	total: 1m 39s	remaining: 26m 58s
# 5000:	learn: 0.9363833	test: 0.9027198	best: 0.9027198 (5000)	total: 1m 49s	remaining: 26m 32s
# 5500:	learn: 0.9394007	test: 0.9027690	best: 0.9028460 (5247)	total: 1m 59s	remaining: 26m 10s
# 6000:	learn: 0.9422275	test: 0.9028951	best: 0.9028968 (5999)	total: 2m 9s	remaining: 25m 50s
# 6500:	learn: 0.9449818	test: 0.9030176	best: 0.9030563 (6453)	total: 2m 19s	remaining: 25m 33s
# bestTest = 0.9030563235
# bestIteration = 6453
# Shrink model to first 6454 iterations.
# Fold score: 0.90306
# fold 2
# 0:	learn: 0.5831620	test: 0.5872198	best: 0.5872198 (0)	total: 26.6ms	remaining: 34m 29s
# 500:	learn: 0.8733738	test: 0.8604147	best: 0.8604147 (500)	total: 10.5s	remaining: 27m 2s
# 1000:	learn: 0.8957535	test: 0.8794743	best: 0.8794743 (1000)	total: 20.6s	remaining: 26m 21s
# 1500:	learn: 0.9069135	test: 0.8876393	best: 0.8876393 (1500)	total: 30.7s	remaining: 26m 2s
# 2000:	learn: 0.9139329	test: 0.8915569	best: 0.8915578 (1997)	total: 41s	remaining: 25m 51s
# 2500:	learn: 0.9190762	test: 0.8937234	best: 0.8937278 (2499)	total: 51.4s	remaining: 25m 47s
# 3000:	learn: 0.9234891	test: 0.8949601	best: 0.8949601 (3000)	total: 1m 1s	remaining: 25m 44s
# 3500:	learn: 0.9273455	test: 0.8955820	best: 0.8955870 (3487)	total: 1m 12s	remaining: 25m 37s
# 4000:	learn: 0.9308371	test: 0.8960053	best: 0.8960205 (3971)	total: 1m 22s	remaining: 25m 20s
# 4500:	learn: 0.9340859	test: 0.8961671	best: 0.8962058 (4431)	total: 1m 32s	remaining: 25m 6s
# 5000:	learn: 0.9372427	test: 0.8962621	best: 0.8962768 (4845)	total: 1m 42s	remaining: 24m 53s
# 5500:	learn: 0.9402319	test: 0.8964006	best: 0.8964058 (5492)	total: 1m 53s	remaining: 24m 44s
# 6000:	learn: 0.9430012	test: 0.8963686	best: 0.8964479 (5730)	total: 2m 3s	remaining: 24m 36s
# bestTest = 0.896447897
# bestIteration = 5730
# Shrink model to first 5731 iterations.
# Fold score: 0.89645
# fold 3
# 0:	learn: 0.5887079	test: 0.5904347	best: 0.5904347 (0)	total: 26.5ms	remaining: 34m 20s
# 500:	learn: 0.8727766	test: 0.8620232	best: 0.8620232 (500)	total: 11.9s	remaining: 30m 42s
# 1000:	learn: 0.8954648	test: 0.8802228	best: 0.8802228 (1000)	total: 23.5s	remaining: 30m 1s
# 1500:	learn: 0.9067764	test: 0.8874601	best: 0.8874601 (1500)	total: 33.8s	remaining: 28m 37s
# 2000:	learn: 0.9139153	test: 0.8911882	best: 0.8911882 (2000)	total: 43.8s	remaining: 27m 40s
# 2500:	learn: 0.9191816	test: 0.8929321	best: 0.8929321 (2500)	total: 54s	remaining: 27m 5s
# 3000:	learn: 0.9236281	test: 0.8941258	best: 0.8941268 (2996)	total: 1m 4s	remaining: 26m 37s
# 3500:	learn: 0.9275534	test: 0.8947713	best: 0.8947906 (3479)	total: 1m 14s	remaining: 26m 22s
# 4000:	learn: 0.9310962	test: 0.8952605	best: 0.8952605 (4000)	total: 1m 24s	remaining: 26m 6s
# 4500:	learn: 0.9343631	test: 0.8954111	best: 0.8954678 (4243)	total: 1m 35s	remaining: 25m 47s
# 5000:	learn: 0.9374683	test: 0.8955974	best: 0.8956172 (4984)	total: 1m 45s	remaining: 25m 29s
# 5500:	learn: 0.9404489	test: 0.8957521	best: 0.8957770 (5487)	total: 1m 55s	remaining: 25m 13s
# 6000:	learn: 0.9433067	test: 0.8957720	best: 0.8957924 (5613)	total: 2m 5s	remaining: 24m 57s
# bestTest = 0.8957923651
# bestIteration = 5613
# Shrink model to first 5614 iterations.
# Fold score: 0.89579
# fold 4
# 0:	learn: 0.5880826	test: 0.5912256	best: 0.5912256 (0)	total: 26.4ms	remaining: 34m 11s
# 500:	learn: 0.8730067	test: 0.8608328	best: 0.8608328 (500)	total: 10.7s	remaining: 27m 28s
# 1000:	learn: 0.8956702	test: 0.8802125	best: 0.8802125 (1000)	total: 20.8s	remaining: 26m 36s
# 1500:	learn: 0.9065360	test: 0.8880588	best: 0.8880588 (1500)	total: 30.8s	remaining: 26m 3s
# 5500:	learn: 0.9200564	test: 0.9027852	best: 0.9027852 (5500)	total: 1m 46s	remaining: 23m 13s
# 6000:	learn: 0.9216487	test: 0.9030352	best: 0.9030601 (5924)	total: 1m 55s	remaining: 23m 4s
# 6500:	learn: 0.9231687	test: 0.9030234	best: 0.9030804 (6459)	total: 2m 4s	remaining: 22m 50s
# 7000:	learn: 0.9246306	test: 0.9030838	best: 0.9031029 (6667)	total: 2m 14s	remaining: 22m 39s
# 7500:	learn: 0.9260956	test: 0.9030509	best: 0.9031227 (7061)	total: 2m 24s	remaining: 22m 30s
# bestTest = 0.9031226635
# bestIteration = 7061
# Shrink model to first 7062 iterations.
# Fold score: 0.90312
# fold 2
# 0:	learn: 0.5343982	test: 0.5358832	best: 0.5358832 (0)	total: 23.5ms	remaining: 30m 30s
# 500:	learn: 0.8641735	test: 0.8528066	best: 0.8528250 (499)	total: 9.74s	remaining: 25m 2s
# 1000:	learn: 0.8873892	test: 0.8747889	best: 0.8747889 (1000)	total: 19.2s	remaining: 24m 30s
# 1500:	learn: 0.8983541	test: 0.8849750	best: 0.8849750 (1500)	total: 28.5s	remaining: 24m 8s
# 2000:	learn: 0.9044233	test: 0.8896948	best: 0.8896948 (2000)	total: 37.8s	remaining: 23m 51s
# 2500:	learn: 0.9084577	test: 0.8927332	best: 0.8927332 (2500)	total: 47.2s	remaining: 23m 39s
# 3000:	learn: 0.9115170	test: 0.8940985	best: 0.8940985 (3000)	total: 56.5s	remaining: 23m 26s
# 3500:	learn: 0.9141245	test: 0.8953022	best: 0.8953195 (3494)	total: 1m 5s	remaining: 23m 19s
# 4000:	learn: 0.9162263	test: 0.8958249	best: 0.8958384 (3990)	total: 1m 15s	remaining: 23m 9s
# 4500:	learn: 0.9180980	test: 0.8962094	best: 0.8962098 (4499)	total: 1m 24s	remaining: 22m 57s
# 5000:	learn: 0.9198697	test: 0.8964298	best: 0.8964465 (4941)	total: 1m 34s	remaining: 22m 48s
# 5500:	learn: 0.9215959	test: 0.8966361	best: 0.8966450 (5452)	total: 1m 43s	remaining: 22m 40s
# 6000:	learn: 0.9231610	test: 0.8965986	best: 0.8967067 (5724)	total: 1m 53s	remaining: 22m 34s
# bestTest = 0.8967067301
# bestIteration = 5724
# Shrink model to first 5725 iterations.
# Fold score: 0.89671
# fold 3
# 0:	learn: 0.5434044	test: 0.5418699	best: 0.5418699 (0)	total: 23.5ms	remaining: 30m 27s
# 500:	learn: 0.8627160	test: 0.8540711	best: 0.8540711 (500)	total: 10.8s	remaining: 27m 42s
# 1000:	learn: 0.8873944	test: 0.8760064	best: 0.8760064 (1000)	total: 21.3s	remaining: 27m 11s
# 1500:	learn: 0.8981825	test: 0.8846329	best: 0.8846329 (1500)	total: 31.8s	remaining: 26m 53s
# 2000:	learn: 0.9043529	test: 0.8891715	best: 0.8891715 (2000)	total: 42.1s	remaining: 26m 34s
# 2500:	learn: 0.9084221	test: 0.8916953	best: 0.8916957 (2499)	total: 51.8s	remaining: 25m 58s
# 3000:	learn: 0.9115847	test: 0.8934390	best: 0.8934435 (2996)	total: 1m 1s	remaining: 25m 26s
# 3500:	learn: 0.9141265	test: 0.8943402	best: 0.8943498 (3491)	total: 1m 11s	remaining: 25m 7s
# 4000:	learn: 0.9162251	test: 0.8949828	best: 0.8949828 (4000)	total: 1m 20s	remaining: 24m 50s
# 4500:	learn: 0.9181006	test: 0.8953458	best: 0.8953586 (4340)	total: 1m 30s	remaining: 24m 36s
# 5000:	learn: 0.9198607	test: 0.8956580	best: 0.8956672 (4989)	total: 1m 40s	remaining: 24m 22s
# 5500:	learn: 0.9215451	test: 0.8957844	best: 0.8957844 (5500)	total: 1m 50s	remaining: 24m 6s
# 6000:	learn: 0.9231625	test: 0.8958320	best: 0.8958583 (5913)	total: 1m 59s	remaining: 23m 54s
# bestTest = 0.8958583474
# bestIteration = 5913
# Shrink model to first 5914 iterations.
# Fold score: 0.89586
# fold 4
# 0:	learn: 0.5457055	test: 0.5376610	best: 0.5376610 (0)	total: 23.8ms	remaining: 30m 51s
# 500:	learn: 0.8639145	test: 0.8533405	best: 0.8533405 (500)	total: 9.74s	remaining: 25m 2s
# 1000:	learn: 0.8876038	test: 0.8758012	best: 0.8758012 (1000)	total: 19.1s	remaining: 24m 26s
# 1500:	learn: 0.8980561	test: 0.8849482	best: 0.8849482 (1500)	total: 28.6s	remaining: 24m 14s
# 2000:	learn: 0.9041166	test: 0.8898193	best: 0.8898215 (1998)	total: 38.6s	remaining: 24m 20s
# 2500:	learn: 0.9081499	test: 0.8923526	best: 0.8923526 (2500)	total: 48.1s	remaining: 24m 9s
# 3000:	learn: 0.9112048	test: 0.8939880	best: 0.8939880 (3000)	total: 57.6s	remaining: 23m 54s
# 3500:	learn: 0.9137712	test: 0.8949476	best: 0.8949514 (3499)	total: 1m 7s	remaining: 23m 42s
# 4000:	learn: 0.9159654	test: 0.8956735	best: 0.8956770 (3980)	total: 1m 16s	remaining: 23m 33s
# 4500:	learn: 0.9178653	test: 0.8960549	best: 0.8960583 (4497)	total: 1m 26s	remaining: 23m 22s
# 5000:	learn: 0.9196300	test: 0.8962148	best: 0.8962327 (4945)	total: 1m 35s	remaining: 23m 14s
# 5500:	learn: 0.9212870	test: 0.8964340	best: 0.8964607 (5462)	total: 1m 45s	remaining: 23m 7s
# 6000:	learn: 0.9228558	test: 0.8965580	best: 0.8965680 (5990)	total: 1m 55s	remaining: 22m 58s
# 6500:	learn: 0.9243747	test: 0.8965920	best: 0.8966203 (6325)	total: 2m 4s	remaining: 22m 49s
# bestTest = 0.8966203332
# bestIteration = 6325
# Shrink model to first 6326 iterations.
# Fold score: 0.89662
# CV score: 0.89909
# |  5        |  0.8991   |  2.099    |  0.05828  |  97.0     |  5.034    |
# fold 0
# 0:	learn: 0.5933810	test: 0.5807535	best: 0.5807535 (0)	total: 24.4ms	remaining: 31m 37s
# 500:	learn: 0.8894203	test: 0.8805993	best: 0.8805993 (500)	total: 10.5s	remaining: 26m 58s
# 1000:	learn: 0.9084690	test: 0.8940428	best: 0.8940428 (1000)	total: 20.8s	remaining: 26m 37s
# 1500:	learn: 0.9183119	test: 0.8985487	best: 0.8985671 (1488)	total: 31.5s	remaining: 26m 41s
# 2000:	learn: 0.9255996	test: 0.9003029	best: 0.9003062 (1990)	total: 42.2s	remaining: 26m 37s
# 2500:	learn: 0.9316921	test: 0.9013981	best: 0.9013990 (2495)	total: 52.7s	remaining: 26m 26s
# 3000:	learn: 0.9370531	test: 0.9018091	best: 0.9018183 (2998)	total: 1m 3s	remaining: 26m 17s
# 3500:	learn: 0.9420723	test: 0.9022286	best: 0.9022375 (3498)	total: 1m 13s	remaining: 26m 7s
# 4000:	learn: 0.9466755	test: 0.9023124	best: 0.9023895 (3711)	total: 1m 24s	remaining: 25m 57s
# 4500:	learn: 0.9510382	test: 0.9023405	best: 0.9024179 (4239)	total: 1m 35s	remaining: 25m 47s
# bestTest = 0.9024178982
# bestIteration = 4239
# Shrink model to first 4240 iterations.
# Fold score: 0.90242
# fold 1
# 0:	learn: 0.5891300	test: 0.5772779	best: 0.5772779 (0)	total: 25.2ms	remaining: 32m 38s
# 500:	learn: 0.8892447	test: 0.8813187	best: 0.8813187 (500)	total: 11.8s	remaining: 30m 18s
# 1000:	learn: 0.9084141	test: 0.8946688	best: 0.8946688 (1000)	total: 22.8s	remaining: 29m 5s
# 1500:	learn: 0.9185271	test: 0.8993596	best: 0.8993596 (1500)	total: 33s	remaining: 27m 59s
# 2000:	learn: 0.9255651	test: 0.9009757	best: 0.9009823 (1999)	total: 43.3s	remaining: 27m 19s
# 2500:	learn: 0.9316076	test: 0.9018423	best: 0.9018423 (2500)	total: 53.3s	remaining: 26m 45s
# 3000:	learn: 0.9371035	test: 0.9022748	best: 0.9023277 (2880)	total: 1m 3s	remaining: 26m 18s
# 3500:	learn: 0.9422363	test: 0.9024451	best: 0.9024785 (3434)	total: 1m 13s	remaining: 25m 58s
# bestTest = 0.9024785459
# bestIteration = 3434
# Shrink model to first 3435 iterations.
# Fold score: 0.90248
# fold 2
# 0:	learn: 0.5883992	test: 0.5930114	best: 0.5930114 (0)	total: 24.4ms	remaining: 31m 34s
# 500:	learn: 0.8904685	test: 0.8748803	best: 0.8748803 (500)	total: 10.8s	remaining: 27m 49s
# 1000:	learn: 0.9094757	test: 0.8892186	best: 0.8892186 (1000)	total: 21.4s	remaining: 27m 22s
# 1500:	learn: 0.9193524	test: 0.8934960	best: 0.8935013 (1499)	total: 31.9s	remaining: 27m 3s
# 2000:	learn: 0.9265103	test: 0.8947207	best: 0.8947640 (1977)	total: 42.5s	remaining: 26m 48s
# 2500:	learn: 0.9324523	test: 0.8954285	best: 0.8954285 (2500)	total: 53.3s	remaining: 26m 42s
# 3000:	learn: 0.9377755	test: 0.8955353	best: 0.8956744 (2903)	total: 1m 3s	remaining: 26m 23s
# 3500:	learn: 0.9428757	test: 0.8956985	best: 0.8958023 (3323)	total: 1m 13s	remaining: 26m 1s
# bestTest = 0.8958022594
# bestIteration = 3323
# Shrink model to first 3324 iterations.
# Fold score: 0.89580
# fold 3
# 0:	learn: 0.5945189	test: 0.5918207	best: 0.5918207 (0)	total: 25.2ms	remaining: 32m 39s
# 500:	learn: 0.8903203	test: 0.8752009	best: 0.8752009 (500)	total: 10.9s	remaining: 27m 59s
# 1000:	learn: 0.9099254	test: 0.8885585	best: 0.8885585 (1000)	total: 21.4s	remaining: 27m 23s
# 1500:	learn: 0.9194976	test: 0.8923870	best: 0.8923870 (1500)	total: 31.8s	remaining: 26m 54s
# 2000:	learn: 0.9264765	test: 0.8939612	best: 0.8939624 (1999)	total: 42s	remaining: 26m 29s
# 2500:	learn: 0.9325681	test: 0.8946074	best: 0.8946512 (2489)	total: 52.1s	remaining: 26m 8s
# 3000:	learn: 0.9381060	test: 0.8948178	best: 0.8949122 (2836)	total: 1m 2s	remaining: 25m 50s
# 3500:	learn: 0.9432240	test: 0.8949332	best: 0.8950387 (3446)	total: 1m 12s	remaining: 25m 34s
# bestTest = 0.8950387239
# bestIteration = 3446
# Shrink model to first 3447 iterations.
# Fold score: 0.89504
# fold 4
# 0:	learn: 0.5927350	test: 0.5975310	best: 0.5975310 (0)	total: 26.4ms	remaining: 34m 15s
# 500:	learn: 0.8904658	test: 0.8757324	best: 0.8757324 (500)	total: 10.5s	remaining: 26m 52s
# 1000:	learn: 0.9094691	test: 0.8895028	best: 0.8895028 (1000)	total: 20.7s	remaining: 26m 25s
# 1500:	learn: 0.9192744	test: 0.8938757	best: 0.8938757 (1500)	total: 30.9s	remaining: 26m 12s
# 2000:	learn: 0.9264093	test: 0.8957890	best: 0.8957919 (1998)	total: 41.1s	remaining: 25m 55s
# 2500:	learn: 0.9324790	test: 0.8964185	best: 0.8964601 (2445)	total: 51.1s	remaining: 25m 37s
# 3000:	learn: 0.9378197	test: 0.8965645	best: 0.8966619 (2764)	total: 1m 1s	remaining: 25m 21s
# 3500:	learn: 0.9427761	test: 0.8965192	best: 0.8966743 (3291)	total: 1m 11s	remaining: 25m 10s
# bestTest = 0.8966742754
# bestIteration = 3291
# Shrink model to first 3292 iterations.
# Fold score: 0.89667
# CV score: 0.89847
# |  6        |  0.8985   |  3.589    |  0.05976  |  37.11    |  5.149    |
# fold 0
# 0:	learn: 0.5465737	test: 0.5387202	best: 0.5387202 (0)	total: 24.2ms	remaining: 31m 25s
# 500:	learn: 0.8897702	test: 0.8824079	best: 0.8824079 (500)	total: 10.4s	remaining: 26m 36s
# 1000:	learn: 0.9066469	test: 0.8954442	best: 0.8954442 (1000)	total: 20.8s	remaining: 26m 31s
# 1500:	learn: 0.9150133	test: 0.8993761	best: 0.8993761 (1500)	total: 31.1s	remaining: 26m 20s
# 2000:	learn: 0.9211184	test: 0.9008804	best: 0.9008966 (1989)	total: 41.4s	remaining: 26m 9s
# 2500:	learn: 0.9259750	test: 0.9016041	best: 0.9016288 (2394)	total: 51.8s	remaining: 26m
# 3000:	learn: 0.9305841	test: 0.9017912	best: 0.9018088 (2946)	total: 1m 2s	remaining: 25m 53s
# 3500:	learn: 0.9348238	test: 0.9018618	best: 0.9019149 (3088)	total: 1m 12s	remaining: 25m 44s
# 4000:	learn: 0.9387938	test: 0.9018760	best: 0.9020280 (3709)	total: 1m 23s	remaining: 25m 32s
# bestTest = 0.9020280242
# bestIteration = 3709
# Shrink model to first 3710 iterations.
# Fold score: 0.90203
# fold 1
# 0:	learn: 0.5446421	test: 0.5441677	best: 0.5441677 (0)	total: 25.4ms	remaining: 32m 52s
# 500:	learn: 0.8895661	test: 0.8833980	best: 0.8833980 (500)	total: 10.3s	remaining: 26m 21s
# 1000:	learn: 0.9065312	test: 0.8959747	best: 0.8959747 (1000)	total: 20.1s	remaining: 25m 39s
# 1500:	learn: 0.9147939	test: 0.8999196	best: 0.8999196 (1500)	total: 29.8s	remaining: 25m 15s
# 2000:	learn: 0.9206030	test: 0.9017714	best: 0.9017740 (1999)	total: 39.9s	remaining: 25m 10s
# 2500:	learn: 0.9256054	test: 0.9025871	best: 0.9025871 (2500)	total: 50s	remaining: 25m 4s
# 3000:	learn: 0.9301631	test: 0.9028945	best: 0.9029893 (2880)	total: 1m	remaining: 24m 56s
# 3500:	learn: 0.9345515	test: 0.9029412	best: 0.9031073 (3300)	total: 1m 10s	remaining: 24m 45s
# bestTest = 0.9031073451
# bestIteration = 3300
# Shrink model to first 3301 iterations.
# Fold score: 0.90311
# fold 2
# 0:	learn: 0.5398178	test: 0.5414064	best: 0.5414064 (0)	total: 18.9ms	remaining: 24m 31s
# 500:	learn: 0.8906904	test: 0.8766952	best: 0.8766952 (500)	total: 9.37s	remaining: 24m 5s
# 1000:	learn: 0.9079795	test: 0.8900710	best: 0.8900710 (1000)	total: 18.9s	remaining: 24m 8s
# 1500:	learn: 0.9162347	test: 0.8940584	best: 0.8940664 (1499)	total: 28.5s	remaining: 24m 7s
# 2000:	learn: 0.9220710	test: 0.8952407	best: 0.8952572 (1995)	total: 38.3s	remaining: 24m 10s
# 2500:	learn: 0.9268746	test: 0.8955915	best: 0.8956814 (2449)	total: 48.4s	remaining: 24m 16s
# bestTest = 0.8956813812
# bestIteration = 2449
# Shrink model to first 2450 iterations.
# Fold score: 0.89568
# fold 3
# 0:	learn: 0.5461745	test: 0.5546700	best: 0.5546700 (0)	total: 18.8ms	remaining: 24m 18s
# 500:	learn: 0.8904626	test: 0.8773679	best: 0.8773679 (500)	total: 9.52s	remaining: 24m 28s
# 1000:	learn: 0.9080188	test: 0.8896900	best: 0.8896989 (999)	total: 19s	remaining: 24m 17s
# 1500:	learn: 0.9163712	test: 0.8931803	best: 0.8931803 (1500)	total: 28.5s	remaining: 24m 8s
# 2000:	learn: 0.9221986	test: 0.8944668	best: 0.8944668 (2000)	total: 38s	remaining: 23m 58s
# 2500:	learn: 0.9271083	test: 0.8949093	best: 0.8949887 (2450)	total: 47.4s	remaining: 23m 46s
# bestTest = 0.894988656
# bestIteration = 2450
# Shrink model to first 2451 iterations.
# Fold score: 0.89499
# fold 4
# 0:	learn: 0.5503531	test: 0.5382556	best: 0.5382556 (0)	total: 23.3ms	remaining: 30m 15s
# 500:	learn: 0.8907456	test: 0.8771910	best: 0.8772089 (499)	total: 10.3s	remaining: 26m 22s
# 1000:	learn: 0.9075814	test: 0.8901584	best: 0.8901584 (1000)	total: 20.5s	remaining: 26m 12s
# 1500:	learn: 0.9161165	test: 0.8940412	best: 0.8940412 (1500)	total: 31.1s	remaining: 26m 18s
# 2000:	learn: 0.9220327	test: 0.8955171	best: 0.8955217 (1989)	total: 41.3s	remaining: 26m 2s
# 2500:	learn: 0.9270484	test: 0.8961934	best: 0.8962187 (2498)	total: 51.3s	remaining: 25m 43s
# 3000:	learn: 0.9315552	test: 0.8961464	best: 0.8963421 (2695)	total: 1m 1s	remaining: 25m 26s
# bestTest = 0.8963420689
# bestIteration = 2695
# Shrink model to first 2696 iterations.
# Fold score: 0.89634
# CV score: 0.89845
# |  7        |  0.8985   |  2.629    |  0.0842   |  96.95    |  16.83    |
# fold 0
# 0:	learn: 0.5386786	test: 0.5320831	best: 0.5320831 (0)	total: 21.7ms	remaining: 28m 6s
# 500:	learn: 0.8768984	test: 0.8719348	best: 0.8719827 (498)	total: 9.63s	remaining: 24m 45s
# 1000:	learn: 0.8965317	test: 0.8895169	best: 0.8895169 (1000)	total: 19.1s	remaining: 24m 23s
# 1500:	learn: 0.9048684	test: 0.8958929	best: 0.8958929 (1500)	total: 28.6s	remaining: 24m 15s
# 2000:	learn: 0.9099171	test: 0.8989366	best: 0.8989366 (2000)	total: 38.1s	remaining: 24m 1s
# 2500:	learn: 0.9133968	test: 0.9004966	best: 0.9005041 (2498)	total: 47.6s	remaining: 23m 52s
# 3000:	learn: 0.9164780	test: 0.9014402	best: 0.9014540 (2996)	total: 57s	remaining: 23m 39s
# 3500:	learn: 0.9191794	test: 0.9020999	best: 0.9021181 (3483)	total: 1m 6s	remaining: 23m 28s
# 4000:	learn: 0.9215786	test: 0.9023100	best: 0.9023286 (3906)	total: 1m 15s	remaining: 23m 20s
# 4500:	learn: 0.9238174	test: 0.9024316	best: 0.9024566 (4476)	total: 1m 25s	remaining: 23m 15s
# 5000:	learn: 0.9259459	test: 0.9024563	best: 0.9024589 (4809)	total: 1m 35s	remaining: 23m 4s
# 5500:	learn: 0.9280511	test: 0.9026031	best: 0.9026120 (5495)	total: 1m 44s	remaining: 22m 52s
# 6000:	learn: 0.9299967	test: 0.9027012	best: 0.9027528 (5954)	total: 1m 53s	remaining: 22m 41s
# bestTest = 0.9027527571
# bestIteration = 5954
# Shrink model to first 5955 iterations.
# Fold score: 0.90275
# fold 1
# 0:	learn: 0.5399791	test: 0.5373605	best: 0.5373605 (0)	total: 21.7ms	remaining: 28m 9s
# 500:	learn: 0.8764766	test: 0.8720178	best: 0.8720178 (500)	total: 9.7s	remaining: 24m 55s
# 1000:	learn: 0.8964437	test: 0.8898504	best: 0.8898504 (1000)	total: 19.2s	remaining: 24m 32s
# 1500:	learn: 0.9049752	test: 0.8964876	best: 0.8964978 (1498)	total: 28.8s	remaining: 24m 21s
# 2000:	learn: 0.9099702	test: 0.8996770	best: 0.8996770 (2000)	total: 38.1s	remaining: 24m 3s
# 2500:	learn: 0.9135686	test: 0.9011496	best: 0.9011496 (2500)	total: 47.6s	remaining: 23m 52s
# 3000:	learn: 0.9164014	test: 0.9020761	best: 0.9020786 (2998)	total: 57.1s	remaining: 23m 42s
# 3500:	learn: 0.9191475	test: 0.9023247	best: 0.9023566 (3475)	total: 1m 6s	remaining: 23m 33s
# 4000:	learn: 0.9215212	test: 0.9026449	best: 0.9027103 (3853)	total: 1m 16s	remaining: 23m 25s
# 4500:	learn: 0.9238560	test: 0.9028513	best: 0.9028921 (4203)	total: 1m 25s	remaining: 23m 12s
# bestTest = 0.9028921127
# bestIteration = 4203
# Shrink model to first 4204 iterations.
# Fold score: 0.90289
# fold 2
# 0:	learn: 0.5343982	test: 0.5358832	best: 0.5358832 (0)	total: 23ms	remaining: 29m 47s
# 500:	learn: 0.8784278	test: 0.8659262	best: 0.8659262 (500)	total: 9.96s	remaining: 25m 36s
# 1000:	learn: 0.8977168	test: 0.8838865	best: 0.8838888 (999)	total: 19.4s	remaining: 24m 44s
# 1500:	learn: 0.9064248	test: 0.8911995	best: 0.8911995 (1500)	total: 28.9s	remaining: 24m 27s
# 2000:	learn: 0.9113441	test: 0.8939325	best: 0.8939463 (1992)	total: 38.7s	remaining: 24m 26s
# 2500:	learn: 0.9148289	test: 0.8952003	best: 0.8952003 (2500)	total: 48.3s	remaining: 24m 15s
# 3000:	learn: 0.9178487	test: 0.8956673	best: 0.8957871 (2830)	total: 57.8s	remaining: 23m 59s
# 3500:	learn: 0.9205760	test: 0.8961526	best: 0.8961638 (3489)	total: 1m 7s	remaining: 23m 55s
# 4000:	learn: 0.9228256	test: 0.8961675	best: 0.8962097 (3560)	total: 1m 17s	remaining: 23m 48s
# bestTest = 0.896209687
# bestIteration = 3560
# Shrink model to first 3561 iterations.
# Fold score: 0.89621
# fold 3
# 0:	learn: 0.5434044	test: 0.5418699	best: 0.5418699 (0)	total: 23.9ms	remaining: 31m 1s
# 500:	learn: 0.8778649	test: 0.8677728	best: 0.8677728 (500)	total: 10.9s	remaining: 27m 56s
# 1000:	learn: 0.8975645	test: 0.8845645	best: 0.8845645 (1000)	total: 20.8s	remaining: 26m 33s
# 1500:	learn: 0.9059344	test: 0.8900244	best: 0.8900244 (1500)	total: 30.3s	remaining: 25m 39s
# 2000:	learn: 0.9111902	test: 0.8925623	best: 0.8925841 (1993)	total: 39.9s	remaining: 25m 12s
# 2500:	learn: 0.9148668	test: 0.8939455	best: 0.8939455 (2500)	total: 49.8s	remaining: 24m 58s
# 3000:	learn: 0.9178495	test: 0.8947232	best: 0.8947486 (2989)	total: 1m	remaining: 24m 56s
# 3500:	learn: 0.9203619	test: 0.8950862	best: 0.8951100 (3462)	total: 1m 10s	remaining: 24m 49s
# 4000:	learn: 0.9227666	test: 0.8953706	best: 0.8953796 (3994)	total: 1m 20s	remaining: 24m 42s
# 4500:	learn: 0.9249761	test: 0.8953211	best: 0.8954188 (4210)	total: 1m 30s	remaining: 24m 35s
# bestTest = 0.8954188228
# bestIteration = 4210
# Shrink model to first 4211 iterations.
# Fold score: 0.89542
# fold 4
# 0:	learn: 0.5457055	test: 0.5376610	best: 0.5376610 (0)	total: 25.1ms	remaining: 32m 33s
# 500:	learn: 0.8785921	test: 0.8672364	best: 0.8672364 (500)	total: 10.9s	remaining: 28m 2s
# 1000:	learn: 0.8974689	test: 0.8843529	best: 0.8843529 (1000)	total: 21.7s	remaining: 27m 41s
# 1500:	learn: 0.9058802	test: 0.8911456	best: 0.8911476 (1499)	total: 31.9s	remaining: 27m 1s
# 2000:	learn: 0.9110000	test: 0.8942627	best: 0.8942789 (1996)	total: 41.8s	remaining: 26m 23s
# ...
# 500:	learn: 0.8665931	test: 0.8549376	best: 0.8549376 (500)	total: 11.1s	remaining: 28m 35s
# 1000:	learn: 0.8899725	test: 0.8760327	best: 0.8760327 (1000)	total: 21.3s	remaining: 27m 16s
# 1500:	learn: 0.9011958	test: 0.8852354	best: 0.8852354 (1500)	total: 31.1s	remaining: 26m 21s
# 2000:	learn: 0.9077887	test: 0.8899003	best: 0.8899003 (2000)	total: 41.3s	remaining: 26m 4s
# 2500:	learn: 0.9124489	test: 0.8925881	best: 0.8925909 (2499)	total: 51.4s	remaining: 25m 48s
# 3000:	learn: 0.9161840	test: 0.8940620	best: 0.8940620 (3000)	total: 1m 1s	remaining: 25m 29s
# 3500:	learn: 0.9194233	test: 0.8950201	best: 0.8950227 (3494)	total: 1m 11s	remaining: 25m 9s
# 4000:	learn: 0.9223247	test: 0.8955858	best: 0.8955953 (3971)	total: 1m 20s	remaining: 24m 52s
# 4500:	learn: 0.9249160	test: 0.8960350	best: 0.8960415 (4480)	total: 1m 31s	remaining: 24m 47s
# 5000:	learn: 0.9274708	test: 0.8962211	best: 0.8962694 (4841)	total: 1m 41s	remaining: 24m 40s
# 5500:	learn: 0.9298359	test: 0.8964018	best: 0.8964200 (5455)	total: 1m 51s	remaining: 24m 26s
# 6000:	learn: 0.9320722	test: 0.8965216	best: 0.8965380 (5922)	total: 2m 1s	remaining: 24m 13s
# 6500:	learn: 0.9342401	test: 0.8964896	best: 0.8965759 (6263)	total: 2m 11s	remaining: 24m 4s
# bestTest = 0.8965759277
# bestIteration = 6263
# Shrink model to first 6264 iterations.
# Fold score: 0.89658
# fold 3
# 0:	learn: 0.5461745	test: 0.5546700	best: 0.5546700 (0)	total: 25.3ms	remaining: 32m 46s
# 500:	learn: 0.8653415	test: 0.8559821	best: 0.8559821 (500)	total: 11.3s	remaining: 29m 3s
# 1000:	learn: 0.8897227	test: 0.8766028	best: 0.8766028 (1000)	total: 22.2s	remaining: 28m 20s
# 1500:	learn: 0.9008633	test: 0.8850714	best: 0.8850714 (1500)	total: 33.1s	remaining: 28m
# 2000:	learn: 0.9077567	test: 0.8894396	best: 0.8894461 (1996)	total: 44.1s	remaining: 27m 48s
# 2500:	learn: 0.9125575	test: 0.8918758	best: 0.8918758 (2500)	total: 55s	remaining: 27m 34s
# 3000:	learn: 0.9163512	test: 0.8935026	best: 0.8935200 (2990)	total: 1m 5s	remaining: 27m 21s
# 3500:	learn: 0.9196090	test: 0.8943598	best: 0.8943746 (3479)	total: 1m 16s	remaining: 26m 59s
# 4000:	learn: 0.9224467	test: 0.8949453	best: 0.8949453 (4000)	total: 1m 26s	remaining: 26m 31s
# 4500:	learn: 0.9250962	test: 0.8952234	best: 0.8952421 (4402)	total: 1m 36s	remaining: 26m 8s
# 5000:	learn: 0.9275551	test: 0.8956729	best: 0.8956800 (4993)	total: 1m 46s	remaining: 25m 50s
# 5500:	learn: 0.9298639	test: 0.8957782	best: 0.8958008 (5489)	total: 1m 56s	remaining: 25m 33s
# 6000:	learn: 0.9321617	test: 0.8958332	best: 0.8958395 (5748)	total: 2m 6s	remaining: 25m 18s
# 6500:	learn: 0.9342990	test: 0.8956446	best: 0.8958482 (6054)	total: 2m 17s	remaining: 25m 3s
# bestTest = 0.8958482444
# bestIteration = 6054
# Shrink model to first 6055 iterations.
# Fold score: 0.89585
# fold 4
# 0:	learn: 0.5503531	test: 0.5382556	best: 0.5382556 (0)	total: 25.2ms	remaining: 32m 42s
# 500:	learn: 0.8666320	test: 0.8560415	best: 0.8560415 (500)	total: 11.2s	remaining: 28m 55s
# 1000:	learn: 0.8901497	test: 0.8771959	best: 0.8771959 (1000)	total: 22.1s	remaining: 28m 16s
# 1500:	learn: 0.9008564	test: 0.8859458	best: 0.8859458 (1500)	total: 32.2s	remaining: 27m 16s
# 2000:	learn: 0.9075486	test: 0.8905203	best: 0.8905203 (2000)	total: 42.2s	remaining: 26m 36s
# 2500:	learn: 0.9123324	test: 0.8932385	best: 0.8932385 (2500)	total: 52s	remaining: 26m 6s
# 3000:	learn: 0.9161448	test: 0.8946341	best: 0.8946341 (2999)	total: 1m 1s	remaining: 25m 43s
# 3500:	learn: 0.9195020	test: 0.8955364	best: 0.8955394 (3499)	total: 1m 11s	remaining: 25m 25s
# 4000:	learn: 0.9224330	test: 0.8960783	best: 0.8960871 (3967)	total: 1m 21s	remaining: 25m 5s
# 4500:	learn: 0.9250416	test: 0.8964941	best: 0.8965014 (4494)	total: 1m 31s	remaining: 24m 46s
# 5000:	learn: 0.9275139	test: 0.8967263	best: 0.8967326 (4997)	total: 1m 41s	remaining: 24m 31s
# 5500:	learn: 0.9298415	test: 0.8969198	best: 0.8969349 (5464)	total: 1m 50s	remaining: 24m 18s
# 6000:	learn: 0.9321101	test: 0.8970307	best: 0.8970472 (5960)	total: 2m 1s	remaining: 24m 9s
# 6500:	learn: 0.9342753	test: 0.8970189	best: 0.8970596 (6355)	total: 2m 11s	remaining: 24m 3s
# bestTest = 0.8970595598
# bestIteration = 6355
# Shrink model to first 6356 iterations.
# Fold score: 0.89706
# CV score: 0.89920
# |  15       |  0.8992   |  2.933    |  0.0413   |  37.06    |  16.98    |
# fold 0
# 0:	learn: 0.5872358	test: 0.5796279	best: 0.5796279 (0)	total: 26.7ms	remaining: 34m 35s
# 500:	learn: 0.8695207	test: 0.8630429	best: 0.8630429 (500)	total: 11s	remaining: 28m 19s
# 1000:	learn: 0.8924868	test: 0.8831435	best: 0.8831435 (1000)	total: 21.1s	remaining: 27m 1s
# 1500:	learn: 0.9033938	test: 0.8913662	best: 0.8913692 (1498)	total: 31.2s	remaining: 26m 25s
# 2000:	learn: 0.9107642	test: 0.8958123	best: 0.8958123 (2000)	total: 41.5s	remaining: 26m 11s
# 2500:	learn: 0.9162440	test: 0.8983280	best: 0.8983312 (2495)	total: 51.8s	remaining: 25m 59s
# 3000:	learn: 0.9207979	test: 0.8998069	best: 0.8998069 (3000)	total: 1m 2s	remaining: 25m 47s
# 3500:	learn: 0.9246865	test: 0.9005671	best: 0.9005679 (3499)	total: 1m 12s	remaining: 25m 39s
# 4000:	learn: 0.9282585	test: 0.9010176	best: 0.9010202 (3995)	total: 1m 23s	remaining: 25m 30s
# 4500:	learn: 0.9315469	test: 0.9013627	best: 0.9013699 (4466)	total: 1m 33s	remaining: 25m 21s
# 5000:	learn: 0.9346535	test: 0.9016870	best: 0.9016884 (4997)	total: 1m 43s	remaining: 25m 10s
# 5500:	learn: 0.9376059	test: 0.9019183	best: 0.9019223 (5439)	total: 1m 53s	remaining: 24m 56s
# 6000:	learn: 0.9403672	test: 0.9021103	best: 0.9021302 (5942)	total: 2m 4s	remaining: 24m 44s
# 6500:	learn: 0.9430505	test: 0.9023682	best: 0.9023682 (6500)	total: 2m 14s	remaining: 24m 33s
# 7000:	learn: 0.9456651	test: 0.9024948	best: 0.9025106 (6975)	total: 2m 24s	remaining: 24m 25s
# 7500:	learn: 0.9481924	test: 0.9024771	best: 0.9025250 (7095)	total: 2m 35s	remaining: 24m 15s
# bestTest = 0.9025250077
# bestIteration = 7095
# Shrink model to first 7096 iterations.
# Fold score: 0.90252
# fold 1
# 0:	learn: 0.5767654	test: 0.5637967	best: 0.5637967 (0)	total: 26.1ms	remaining: 33m 51s
# 500:	learn: 0.8687939	test: 0.8630412	best: 0.8630420 (499)	total: 11.4s	remaining: 29m 23s
# 1000:	learn: 0.8922732	test: 0.8842799	best: 0.8842799 (1000)	total: 22.7s	remaining: 28m 59s
# 1500:	learn: 0.9036353	test: 0.8923845	best: 0.8923845 (1500)	total: 33.1s	remaining: 28m 3s
# 2000:	learn: 0.9109814	test: 0.8965928	best: 0.8965928 (2000)	total: 43.6s	remaining: 27m 29s
# 2500:	learn: 0.9164940	test: 0.8990194	best: 0.8990194 (2500)	total: 54.1s	remaining: 27m 7s
# 3000:	learn: 0.9209802	test: 0.9006585	best: 0.9006585 (3000)	total: 1m 4s	remaining: 26m 49s
# 3500:	learn: 0.9249679	test: 0.9015216	best: 0.9015307 (3496)	total: 1m 15s	remaining: 26m 33s
# 4000:	learn: 0.9285123	test: 0.9022276	best: 0.9022307 (3997)	total: 1m 25s	remaining: 26m 17s
# 4500:	learn: 0.9318440	test: 0.9025711	best: 0.9025836 (4494)	total: 1m 36s	remaining: 26m 8s
# 5000:	learn: 0.9349794	test: 0.9026756	best: 0.9027010 (4823)	total: 1m 46s	remaining: 25m 54s
# 5500:	learn: 0.9379788	test: 0.9029018	best: 0.9029018 (5500)	total: 1m 57s	remaining: 25m 40s
# 6000:	learn: 0.9407554	test: 0.9030379	best: 0.9030586 (5933)	total: 2m 7s	remaining: 25m 28s
# 6500:	learn: 0.9434738	test: 0.9031855	best: 0.9032012 (6488)	total: 2m 18s	remaining: 25m 17s
# 7000:	learn: 0.9461060	test: 0.9032274	best: 0.9032384 (6767)	total: 2m 28s	remaining: 25m 6s
# 7500:	learn: 0.9486144	test: 0.9032030	best: 0.9032505 (7030)	total: 2m 39s	remaining: 24m 55s
# 8000:	learn: 0.9510241	test: 0.9032282	best: 0.9032994 (7662)	total: 2m 50s	remaining: 24m 45s
# bestTest = 0.9032993913
# bestIteration = 7662
# Shrink model to first 7663 iterations.
# Fold score: 0.90330
# fold 2
# 0:	learn: 0.5831620	test: 0.5872198	best: 0.5872198 (0)	total: 26.1ms	remaining: 33m 51s
# 500:	learn: 0.8712527	test: 0.8584342	best: 0.8584342 (500)	total: 10.7s	remaining: 27m 29s
# 1000:	learn: 0.8935447	test: 0.8775922	best: 0.8775922 (1000)	total: 21s	remaining: 26m 51s
# 1500:	learn: 0.9049350	test: 0.8863191	best: 0.8863191 (1500)	total: 31.7s	remaining: 26m 50s
# 2000:	learn: 0.9122178	test: 0.8907655	best: 0.8907655 (2000)	total: 42.3s	remaining: 26m 42s
# 2500:	learn: 0.9175384	test: 0.8932612	best: 0.8932663 (2499)	total: 53.2s	remaining: 26m 40s
# 3000:	learn: 0.9219904	test: 0.8945797	best: 0.8945898 (2995)	total: 1m 3s	remaining: 26m 23s
# 3500:	learn: 0.9259200	test: 0.8953688	best: 0.8953688 (3500)	total: 1m 13s	remaining: 26m 3s
# 4000:	learn: 0.9295009	test: 0.8957796	best: 0.8958241 (3971)	total: 1m 23s	remaining: 25m 46s
# 4500:	learn: 0.9327125	test: 0.8960853	best: 0.8960853 (4500)	total: 1m 33s	remaining: 25m 29s
# 5000:	learn: 0.9358580	test: 0.8963114	best: 0.8963212 (4975)	total: 1m 44s	remaining: 25m 14s
# 5500:	learn: 0.9387364	test: 0.8964574	best: 0.8964818 (5467)	total: 1m 54s	remaining: 25m 4s
# 6000:	learn: 0.9414965	test: 0.8964517	best: 0.8964945 (5738)	total: 2m 4s	remaining: 24m 54s
# bestTest = 0.8964945078
# bestIteration = 5738
# Shrink model to first 5739 iterations.
# Fold score: 0.89649
# fold 3
# 0:	learn: 0.5887079	test: 0.5904347	best: 0.5904347 (0)	total: 27.9ms	remaining: 36m 7s
# 500:	learn: 0.8703683	test: 0.8598360	best: 0.8598360 (500)	total: 11.2s	remaining: 28m 51s
# 1000:	learn: 0.8933806	test: 0.8785006	best: 0.8785006 (1000)	total: 22.1s	remaining: 28m 18s
# 1500:	learn: 0.9049591	test: 0.8863810	best: 0.8863810 (1500)	total: 32.6s	remaining: 27m 36s
# 2000:	learn: 0.9122158	test: 0.8903322	best: 0.8903322 (2000)	total: 43.1s	remaining: 27m 12s
# 2500:	learn: 0.9177262	test: 0.8924322	best: 0.8924373 (2499)	total: 53.5s	remaining: 26m 50s
# 3000:	learn: 0.9222181	test: 0.8937331	best: 0.8937331 (3000)	total: 1m 3s	remaining: 26m 26s
# 3500:	learn: 0.9261006	test: 0.8944819	best: 0.8944819 (3500)	total: 1m 14s	remaining: 26m 10s
# 4000:	learn: 0.9296162	test: 0.8949757	best: 0.8949757 (4000)	total: 1m 24s	remaining: 25m 56s
# 4500:	learn: 0.9328924	test: 0.8951439	best: 0.8951527 (4457)	total: 1m 34s	remaining: 25m 38s
# 5000:	learn: 0.9359558	test: 0.8954150	best: 0.8954329 (4966)	total: 1m 44s	remaining: 25m 21s
# 5500:	learn: 0.9388942	test: 0.8956385	best: 0.8956574 (5487)	total: 1m 54s	remaining: 25m 7s
# 6000:	learn: 0.9417362	test: 0.8957934	best: 0.8958030 (5996)	total: 2m 4s	remaining: 24m 53s
# bestTest = 0.8958029747
# bestIteration = 5996
# Shrink model to first 5997 iterations.
# Fold score: 0.89580
# fold 4
# 0:	learn: 0.5880826	test: 0.5912256	best: 0.5912256 (0)	total: 28ms	remaining: 36m 17s
# 500:	learn: 0.8709753	test: 0.8590655	best: 0.8590655 (500)	total: 10.7s	remaining: 27m 33s
# 1000:	learn: 0.8934740	test: 0.8786066	best: 0.8786066 (1000)	total: 21s	remaining: 26m 50s
# 1500:	learn: 0.9046241	test: 0.8866520	best: 0.8866520 (1500)	total: 31.3s	remaining: 26m 30s
# 2000:	learn: 0.9118795	test: 0.8909286	best: 0.8909327 (1998)	total: 41.7s	remaining: 26m 19s
# 2500:	learn: 0.9173088	test: 0.8933339	best: 0.8933339 (2500)	total: 52s	remaining: 26m 4s
# 3000:	learn: 0.9217573	test: 0.8949001	best: 0.8949001 (3000)	total: 1m 2s	remaining: 25m 52s
# 3500:	learn: 0.9257582	test: 0.8957648	best: 0.8957711 (3498)	total: 1m 12s	remaining: 25m 40s
# 4000:	learn: 0.9293534	test: 0.8963683	best: 0.8963773 (3981)	total: 1m 22s	remaining: 25m 27s
# 4500:	learn: 0.9326547	test: 0.8968562	best: 0.8968568 (4499)	total: 1m 33s	remaining: 25m 14s
# 5000:	learn: 0.9357280	test: 0.8969287	best: 0.8969783 (4923)	total: 1m 43s	remaining: 25m 5s
# 5500:	learn: 0.9386432	test: 0.8970364	best: 0.8970496 (5480)	total: 1m 54s	remaining: 24m 58s
# 6000:	learn: 0.9414884	test: 0.8971067	best: 0.8971171 (5926)	total: 2m 4s	remaining: 24m 45s
# 6500:	learn: 0.9441431	test: 0.8971048	best: 0.8971692 (6230)	total: 2m 14s	remaining: 24m 32s
# bestTest = 0.8971691728
# bestIteration = 6230
# Shrink model to first 6231 iterations.
# Fold score: 0.89717
# CV score: 0.89908
# |  16       |  0.8991   |  3.933    |  0.03298  |  37.1     |  16.87    |
# fold 0
# 0:	learn: 0.5415841	test: 0.5375753	best: 0.5375753 (0)	total: 23.5ms	remaining: 30m 30s
# 500:	learn: 0.8895202	test: 0.8823342	best: 0.8823342 (500)	total: 10.6s	remaining: 27m 8s
# 1000:	learn: 0.9066308	test: 0.8948608	best: 0.8948608 (1000)	total: 20.5s	remaining: 26m 14s
# 1500:	learn: 0.9150398	test: 0.8989680	best: 0.8989710 (1499)	total: 30.8s	remaining: 26m 5s
# 2000:	learn: 0.9212331	test: 0.9006139	best: 0.9006245 (1977)	total: 40.6s	remaining: 25m 38s
# 2500:	learn: 0.9261752	test: 0.9012063	best: 0.9012232 (2496)	total: 50.6s	remaining: 25m 21s
# 3000:	learn: 0.9308277	test: 0.9014403	best: 0.9015362 (2854)	total: 1m	remaining: 25m 4s
# bestTest = 0.9015361965
# bestIteration = 2854
# Shrink model to first 2855 iterations.
# Fold score: 0.90154
# fold 1
# 0:	learn: 0.5442247	test: 0.5389408	best: 0.5389408 (0)	total: 24.8ms	remaining: 32m 6s
# 500:	learn: 0.8891748	test: 0.8825835	best: 0.8825835 (500)	total: 10.2s	remaining: 26m 14s
# 1000:	learn: 0.9065167	test: 0.8957212	best: 0.8957212 (1000)	total: 20.2s	remaining: 25m 45s
# 1500:	learn: 0.9148642	test: 0.8998909	best: 0.8998909 (1500)	total: 29.9s	remaining: 25m 18s
# 2000:	learn: 0.9209746	test: 0.9014146	best: 0.9014146 (2000)	total: 39.7s	remaining: 25m 4s
# 2500:	learn: 0.9261033	test: 0.9021133	best: 0.9021133 (2500)	total: 49.4s	remaining: 24m 46s
# 3000:	learn: 0.9307281	test: 0.9024517	best: 0.9024871 (2871)	total: 59.4s	remaining: 24m 40s
# 3500:	learn: 0.9353037	test: 0.9025590	best: 0.9025982 (3444)	total: 1m 9s	remaining: 24m 28s
# 4000:	learn: 0.9394068	test: 0.9025376	best: 0.9027002 (3833)	total: 1m 19s	remaining: 24m 21s
# bestTest = 0.9027002454
# bestIteration = 3833
# Shrink model to first 3834 iterations.
# Fold score: 0.90270
# fold 2
# 0:	learn: 0.5398178	test: 0.5414064	best: 0.5414064 (0)	total: 26ms	remaining: 33m 43s
# 500:	learn: 0.8906762	test: 0.8765639	best: 0.8765639 (500)	total: 11.5s	remaining: 29m 30s
# 1000:	learn: 0.9077866	test: 0.8899959	best: 0.8899959 (1000)	total: 21.7s	remaining: 27m 46s
# 1500:	learn: 0.9161139	test: 0.8936917	best: 0.8937135 (1494)	total: 31.7s	remaining: 26m 48s
# 2000:	learn: 0.9220368	test: 0.8951309	best: 0.8951558 (1997)	total: 41.4s	remaining: 26m 7s
# 2500:	learn: 0.9272081	test: 0.8955898	best: 0.8956425 (2485)	total: 51.2s	remaining: 25m 41s
# 3000:	learn: 0.9317815	test: 0.8955863	best: 0.8957772 (2679)	total: 1m	remaining: 25m 17s
# 3500:	learn: 0.9361432	test: 0.8957357	best: 0.8958555 (3309)	total: 1m 10s	remaining: 24m 56s
# bestTest = 0.895855546
# bestIteration = 3309
# Shrink model to first 3310 iterations.
# Fold score: 0.89586
# fold 3
# 0:	learn: 0.5461745	test: 0.5546700	best: 0.5546700 (0)	total: 25.8ms	remaining: 33m 28s
# 500:	learn: 0.8903974	test: 0.8773105	best: 0.8773105 (500)	total: 11.2s	remaining: 28m 43s
# 1000:	learn: 0.9077932	test: 0.8896499	best: 0.8896588 (999)	total: 22.1s	remaining: 28m 17s
# 1500:	learn: 0.9162568	test: 0.8933194	best: 0.8933294 (1489)	total: 33s	remaining: 27m 58s
# 2000:	learn: 0.9224989	test: 0.8947263	best: 0.8947302 (1998)	total: 43.2s	remaining: 27m 15s
# 2500:	learn: 0.9274890	test: 0.8952402	best: 0.8952402 (2500)	total: 53.1s	remaining: 26m 37s
# 3000:	learn: 0.9321088	test: 0.8954940	best: 0.8955505 (2905)	total: 1m 2s	remaining: 26m 5s
# bestTest = 0.8955504894
# bestIteration = 2905
# Shrink model to first 2906 iterations.
# Fold score: 0.89555
# fold 4
# 0:	learn: 0.5503531	test: 0.5382556	best: 0.5382556 (0)	total: 24.4ms	remaining: 31m 33s
# 500:	learn: 0.8904788	test: 0.8769022	best: 0.8769022 (500)	total: 10.8s	remaining: 27m 41s
# 1000:	learn: 0.9078119	test: 0.8900012	best: 0.8900033 (999)	total: 21s	remaining: 26m 47s
# 1500:	learn: 0.9161220	test: 0.8936701	best: 0.8936741 (1496)	total: 31s	remaining: 26m 16s
# 2000:	learn: 0.9222168	test: 0.8952484	best: 0.8952581 (1998)	total: 41.3s	remaining: 26m 2s
# 2500:	learn: 0.9273099	test: 0.8961149	best: 0.8961349 (2498)	total: 51.4s	remaining: 25m 47s
# 3000:	learn: 0.9318317	test: 0.8960174	best: 0.8962215 (2589)	total: 1m 1s	remaining: 25m 28s
# bestTest = 0.8962215185
# bestIteration = 2589
# Shrink model to first 2590 iterations.
# Fold score: 0.89622
# CV score: 0.89836
# |  17       |  0.8984   |  2.647    |  0.08321  |  37.05    |  16.96    |
# =========================================================================

# %%
print(cat_BO.max)
cv_cat_for_BO.post_process()
# Out:
# {'target': 0.899199657855096, 'params': {'depth': 2.933487859851115, 'eta': 0.04130271919090765, 'l2_leaf_reg': 37.06153876127521, 'random_strength': 16.97602628576493}}

# %%
max_idx = cv_cat_for_BO.cv_scores_.index(cat_BO.max['target'])

sub_df = pd.DataFrame({'ID_code': test_data['ID_code'], 
                      'target': cv_cat_for_BO.predictions_[max_idx]})
sub_df.to_csv('submissions.csv', index=False)

# %% [markdown]
# Many thanks to [u1234x1234](https://www.kaggle.com/u1234x1234) who shared me the idea of how to save intermediate results in this [discussion](https://www.kaggle.com/c/santander-customer-transaction-prediction/discussion/82621)
