# %% [markdown]
# # Load libraries and Functions

# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

import os
print(os.listdir("../input"))
# Out:
# ['test.csv', 'train.csv', 'sample_submission.csv']

# %%
INT8_MIN    = np.iinfo(np.int8).min
INT8_MAX    = np.iinfo(np.int8).max
INT16_MIN   = np.iinfo(np.int16).min
INT16_MAX   = np.iinfo(np.int16).max
INT32_MIN   = np.iinfo(np.int32).min
INT32_MAX   = np.iinfo(np.int32).max

FLOAT16_MIN = np.finfo(np.float16).min
FLOAT16_MAX = np.finfo(np.float16).max
FLOAT32_MIN = np.finfo(np.float32).min
FLOAT32_MAX = np.finfo(np.float32).max

def memory_usage(data, detail=1):
    if detail:
        display(data.memory_usage())
    memory = data.memory_usage().sum() / (1024*1024)
    print("Memory usage : {0:.2f}MB".format(memory))
    return memory

def compress_dataset(data):
    """
        Compress datatype as small as it can
        Parameters
        ----------
        path: pandas Dataframe

        Returns
        -------
            None
    """
    memory_before_compress = memory_usage(data, 0)
    print()
    length_interval      = 50
    length_float_decimal = 4

    print('='*length_interval)
    for col in data.columns:
        col_dtype = data[col][:100].dtype

        if col_dtype != 'object':
            print("Name: {0:24s} Type: {1}".format(col, col_dtype))
            col_series = data[col]
            col_min = col_series.min()
            col_max = col_series.max()

            if col_dtype == 'float64':
                print(" variable min: {0:15s} max: {1:15s}".format(str(np.round(col_min, length_float_decimal)), str(np.round(col_max, length_float_decimal))))
                if (col_min > FLOAT16_MIN) and (col_max < FLOAT16_MAX):
                    data[col] = data[col].astype(np.float16)
                    print("  float16 min: {0:15s} max: {1:15s}".format(str(FLOAT16_MIN), str(FLOAT16_MAX)))
                    print("compress float64 --> float16")
                elif (col_min > FLOAT32_MIN) and (col_max < FLOAT32_MAX):
                    data[col] = data[col].astype(np.float32)
                    print("  float32 min: {0:15s} max: {1:15s}".format(str(FLOAT32_MIN), str(FLOAT32_MAX)))
                    print("compress float64 --> float32")
                else:
                    pass
                memory_after_compress = memory_usage(data, 0)
                print("Compress Rate: [{0:.2%}]".format((memory_before_compress-memory_after_compress) / memory_before_compress))
                print('='*length_interval)

            if col_dtype == 'int64':
                print(" variable min: {0:15s} max: {1:15s}".format(str(col_min), str(col_max)))
                type_flag = 64
                if (col_min > INT8_MIN/2) and (col_max < INT8_MAX/2):
                    type_flag = 8
                    data[col] = data[col].astype(np.int8)
                    print("     int8 min: {0:15s} max: {1:15s}".format(str(INT8_MIN), str(INT8_MAX)))
                elif (col_min > INT16_MIN) and (col_max < INT16_MAX):
                    type_flag = 16
                    data[col] = data[col].astype(np.int16)
                    print("    int16 min: {0:15s} max: {1:15s}".format(str(INT16_MIN), str(INT16_MAX)))
                elif (col_min > INT32_MIN) and (col_max < INT32_MAX):
                    type_flag = 32
                    data[col] = data[col].astype(np.int32)
                    print("    int32 min: {0:15s} max: {1:15s}".format(str(INT32_MIN), str(INT32_MAX)))
                    type_flag = 1
                else:
                    pass
                memory_after_compress = memory_usage(data, 0)
                print("Compress Rate: [{0:.2%}]".format((memory_before_compress-memory_after_compress) / memory_before_compress))
                if type_flag == 32:
                    print("compress (int64) ==> (int32)")
                elif type_flag == 16:
                    print("compress (int64) ==> (int16)")
                else:
                    print("compress (int64) ==> (int8)")
                print('='*length_interval)

    print()
    memory_after_compress = memory_usage(data, 0)
    print("Compress Rate: [{0:.2%}]".format((memory_before_compress-memory_after_compress) / memory_before_compress))

# %% [markdown]
# # Compress dataset
# my computer has a small ram, and everytime I join a competition, the first thing I will do is to compress my dataset, after compressing, the size of the dataset drop from 619MB to 158MB (70%!!!), you can even set some unsigned datatypes, and the size of your dataset will be smaller. Hope you guys enjoy this competition!

# %%
train = pd.read_csv('../input/train.csv')
test = pd.read_csv('../input/test.csv')

# %%
data = train.append(test)
# Out:
# /opt/conda/lib/python3.6/site-packages/pandas/core/frame.py:6211: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   sort=sort)

# %%
compress_dataset(data)
# Out:
# Memory usage : 619.51MB
#
# ==================================================
# Name: target                   Type: float64
#  variable min: 0.0             max: 1.0
#   float16 min: -65500.0        max: 65500.0
# compress float64 --> float16
# Memory usage : 617.22MB
# Compress Rate: [0.37%]
# ==================================================
# Name: var_0                    Type: float64
#  variable min: 0.1887          max: 22.3234
#   float16 min: -65500.0        max: 65500.0
# compress float64 --> float16
# Memory usage : 614.93MB
# Compress Rate: [0.74%]
# ==================================================
# Name: var_1                    Type: float64
#  variable min: -15.0434        max: 10.3768
#   float16 min: -65500.0        max: 65500.0
# compress float64 --> float16
# Memory usage : 612.64MB
# Compress Rate: [1.11%]
# ==================================================
# Name: var_10                   Type: float64
#  variable min: -22.6724        max: 20.2145
#   float16 min: -65500.0        max: 65500.0
# compress float64 --> float16
# Memory usage : 610.35MB
# Compress Rate: [1.48%]
# ==================================================
# Name: var_100                  Type: float64
#  variable min: -40.949         max: 25.1409
#   float16 min: -65500.0        max: 65500.0
# compress float64 --> float16
# Memory usage : 608.06MB
# Compress Rate: [1.85%]
# ==================================================
# Name: var_101                  Type: float64
#  variable min: -0.6448         max: 29.1565
#   float16 min: -65500.0        max: 65500.0
# compress float64 --> float16
# Memory usage : 605.77MB
# Compress Rate: [2.22%]
# ==================================================
# Name: var_102                  Type: float64
#  variable min: -7.9256         max: 51.9845
#   float16 min: -65500.0        max: 65500.0
# compress float64 --> float16
# Memory usage : 603.49MB
# Compress Rate: [2.59%]
# ==================================================
# Name: var_103                  Type: float64
#  variable min: 0.9675          max: 2.2397
#   float16 min: -65500.0        max: 65500.0
# compress float64 --> float16
# Memory usage : 601.20MB
# Compress Rate: [2.96%]
# ==================================================
# Name: var_104                  Type: float64
#  variable min: 3.8526          max: 19.4736
#   float16 min: -65500.0        max: 65500.0
# compress float64 --> float16
# Memory usage : 598.91MB
# Compress Rate: [3.33%]
# ==================================================
# Name: var_105                  Type: float64
#  variable min: 0.7153          max: 7.2568
#   float16 min: -65500.0        max: 65500.0
# compress float64 --> float16
# Memory usage : 596.62MB
# Compress Rate: [3.69%]
# ==================================================
# Name: var_106                  Type: float64
#  variable min: 0.9424          max: 15.3074
#   float16 min: -65500.0        max: 65500.0
# compress float64 --> float16
# Memory usage : 594.33MB
# Compress Rate: [4.06%]
# ==================================================
# Name: var_107                  Type: float64
#  variable min: -6.5422         max: 46.5666
#   float16 min: -65500.0        max: 65500.0
# compress float64 --> float16
# Memory usage : 592.04MB
# Compress Rate: [4.43%]
# ==================================================
# Name: var_108                  Type: float64
#  variable min: 13.729          max: 14.743
#   float16 min: -65500.0        max: 65500.0
# compress float64 --> float16
# Memory usage : 589.75MB
# Compress Rate: [4.80%]
# ==================================================
# Name: var_109                  Type: float64
#  variable min: 5.0782          max: 32.1734
#   float16 min: -65500.0        max: 65500.0
# compress float64 --> float16
# Memory usage : 587.46MB
# Compress Rate: [5.17%]
# ==================================================
# Name: var_11                   Type: float64
#  variable min: -26.095         max: 17.1887
#   float16 min: -65500.0        max: 65500.0
# compress float64 --> float16
# Memory usage : 585.17MB
# Compress Rate: [5.54%]
# ==================================================
# Name: var_110                  Type: float64
#  variable min: -9.3964         max: 19.5193
#   float16 min: -65500.0        max: 65500.0
# compress float64 --> float16
# Memory usage : 582.89MB
# Compress Rate: [5.91%]
# ==================================================
# Name: var_111                  Type: float64
#  variable min: 2.1942          max: 9.8002
#   float16 min: -65500.0        max: 65500.0
# compress float64 --> float16
# Memory usage : 580.60MB
# Compress Rate: [6.28%]
# ==================================================
# Name: var_112                  Type: float64
#  variable min: -2.3796         max: 8.4317
#   float16 min: -65500.0        max: 65500.0
# compress float64 --> float16
# Memory usage : 578.31MB
# Compress Rate: [6.65%]
# ==================================================
# Name: var_113                  Type: float64
#  variable min: -5.5139         max: 21.9748
#   float16 min: -65500.0        max: 65500.0
# compress float64 --> float16
# Memory usage : 576.02MB
# Compress Rate: [7.02%]
# ==================================================
# Name: var_114                  Type: float64
#  variable min: -0.0505         max: 6.585
#   float16 min: -65500.0        max: 65500.0
# compress float64 --> float16
# Memory usage : 573.73MB
# Compress Rate: [7.39%]
# ==================================================
# Name: var_115                  Type: float64
#  variable min: -6.875          max: 11.9504
#   float16 min: -65500.0        max: 65500.0
# compress float64 --> float16
# Memory usage : 571.44MB
# Compress Rate: [7.76%]
# ==================================================
# Name: var_116                  Type: float64
#  variable min: -3.163          max: 8.1207
#   float16 min: -65500.0        max: 65500.0
# compress float64 --> float16
# Memory usage : 569.15MB
# Compress Rate: [8.13%]
# ==================================================
# Name: var_117                  Type: float64
#  variable min: -37.6073        max: 64.8109
#   float16 min: -65500.0        max: 65500.0
# compress float64 --> float16
# Memory usage : 566.86MB
# Compress Rate: [8.50%]
# ==================================================
# Name: var_118                  Type: float64
#  variable min: -38.2957        max: 25.2635
#   float16 min: -65500.0        max: 65500.0
# compress float64 --> float16
# Memory usage : 564.58MB
# Compress Rate: [8.87%]
# ==================================================
# Name: var_119                  Type: float64
#  variable min: -9.7742         max: 15.6885
#   float16 min: -65500.0        max: 65500.0
# compress float64 --> float16
# Memory usage : 562.29MB
# Compress Rate: [9.24%]
# ==================================================
# Name: var_12                   Type: float64
#  variable min: 13.4245         max: 14.682
#   float16 min: -65500.0        max: 65500.0
# compress float64 --> float16
# Memory usage : 560.00MB
# Compress Rate: [9.61%]
# ==================================================
# Name: var_120                  Type: float64
#  variable min: -19.5415        max: 74.0321
#   float16 min: -65500.0        max: 65500.0
# compress float64 --> float16
# Memory usage : 557.71MB
# Compress Rate: [9.98%]
# ==================================================
# Name: var_121                  Type: float64
#  variable min: 6.3052          max: 17.3074
#   float16 min: -65500.0        max: 65500.0
# compress float64 --> float16
# Memory usage : 555.42MB
# Compress Rate: [10.34%]
# ==================================================
# Name: var_122                  Type: float64
#  variable min: -15.194         max: 18.4714
#   float16 min: -65500.0        max: 65500.0
# compress float64 --> float16
# Memory usage : 553.13MB
# Compress Rate: [10.71%]
# ==================================================
# Name: var_123                  Type: float64
#  variable min: -12.4059        max: 27.6828
#   float16 min: -65500.0        max: 65500.0
# compress float64 --> float16
# Memory usage : 550.84MB
# Compress Rate: [11.08%]
# ==================================================
# Name: var_124                  Type: float64
#  variable min: -7.0538         max: 14.9915
#   float16 min: -65500.0        max: 65500.0
# compress float64 --> float16
# Memory usage : 548.55MB
# Compress Rate: [11.45%]
# ==================================================
# Name: var_125                  Type: float64
#  variable min: 11.4861         max: 13.6642
#   float16 min: -65500.0        max: 65500.0
# compress float64 --> float16
# Memory usage : 546.26MB
# Compress Rate: [11.82%]
# ==================================================
# Name: var_126                  Type: float64
#  variable min: 11.2654         max: 15.5156
#   float16 min: -65500.0        max: 65500.0
# compress float64 --> float16
# Memory usage : 543.98MB
# Compress Rate: [12.19%]
# ==================================================
# Name: var_127                  Type: float64
#  variable min: -8.8769         max: 10.5976
#   float16 min: -65500.0        max: 65500.0
# compress float64 --> float16
# Memory usage : 541.69MB
# Compress Rate: [12.56%]
# ==================================================
# Name: var_128                  Type: float64
#  variable min: -11.7559        max: 9.8096
#   float16 min: -65500.0        max: 65500.0
# compress float64 --> float16
# Memory usage : 539.40MB
# Compress Rate: [12.93%]
# ==================================================
# Name: var_129                  Type: float64
#  variable min: 2.1863          max: 31.2036
#   float16 min: -65500.0        max: 65500.0
# compress float64 --> float16
# Memory usage : 537.11MB
# Compress Rate: [13.30%]
# ==================================================
# Name: var_13                   Type: float64
#  variable min: -6.0111         max: 22.3315
#   float16 min: -65500.0        max: 65500.0
# compress float64 --> float16
# Memory usage : 534.82MB
# Compress Rate: [13.67%]
# ==================================================
# Name: var_130                  Type: float64
#  variable min: 9.5283          max: 14.9895
#   float16 min: -65500.0        max: 65500.0
# compress float64 --> float16
# Memory usage : 532.53MB
# Compress Rate: [14.04%]
# ==================================================
# Name: var_131                  Type: float64
#  variable min: -0.9548         max: 2.1923
#   float16 min: -65500.0        max: 65500.0
# compress float64 --> float16
# Memory usage : 530.24MB
# Compress Rate: [14.41%]
# ==================================================
# Name: var_132                  Type: float64
#  variable min: 2.89            max: 12.5549
#   float16 min: -65500.0        max: 65500.0
# compress float64 --> float16
# Memory usage : 527.95MB
# Compress Rate: [14.78%]
# ==================================================
# Name: var_133                  Type: float64
#  variable min: 5.3593          max: 8.3091
#   float16 min: -65500.0        max: 65500.0
# compress float64 --> float16
# Memory usage : 525.67MB
# Compress Rate: [15.15%]
# ==================================================
# Name: var_134                  Type: float64
#  variable min: -25.002         max: 12.7236
#   float16 min: -65500.0        max: 65500.0
# compress float64 --> float16
# Memory usage : 523.38MB
# Compress Rate: [15.52%]
# ==================================================
# Name: var_135                  Type: float64
#  variable min: -31.3808        max: 21.4128
#   float16 min: -65500.0        max: 65500.0
# compress float64 --> float16
# Memory usage : 521.09MB
# Compress Rate: [15.89%]
# ==================================================
# Name: var_136                  Type: float64
#  variable min: -9.9493         max: 54.5794
#   float16 min: -65500.0        max: 65500.0
# compress float64 --> float16
# Memory usage : 518.80MB
# Compress Rate: [16.26%]
# ==================================================
# Name: var_137                  Type: float64
#  variable min: -9.851          max: 44.4376
#   float16 min: -65500.0        max: 65500.0
# compress float64 --> float16
# Memory usage : 516.51MB
# Compress Rate: [16.63%]
# ==================================================
# Name: var_138                  Type: float64
#  variable min: -16.6974        max: 18.8187
#   float16 min: -65500.0        max: 65500.0
# compress float64 --> float16
# Memory usage : 514.22MB
# Compress Rate: [17.00%]
# ==================================================
# Name: var_139                  Type: float64
#  variable min: -21.2743        max: 37.7304
#   float16 min: -65500.0        max: 65500.0
# compress float64 --> float16
# Memory usage : 511.93MB
# Compress Rate: [17.36%]
# ==================================================
# Name: var_14                   Type: float64
#  variable min: 0.6703          max: 14.9377
#   float16 min: -65500.0        max: 65500.0
# compress float64 --> float16
# Memory usage : 509.64MB
# Compress Rate: [17.73%]
# ==================================================
# Name: var_140                  Type: float64
#  variable min: -15.4595        max: 21.1219
#   float16 min: -65500.0        max: 65500.0
# compress float64 --> float16
# Memory usage : 507.35MB
# Compress Rate: [18.10%]
# ==================================================
# Name: var_141                  Type: float64
#  variable min: -16.6937        max: 23.9658
#   float16 min: -65500.0        max: 65500.0
# compress float64 --> float16
# Memory usage : 505.07MB
# Compress Rate: [18.47%]
# ==================================================
# Name: var_142                  Type: float64
#  variable min: -7.3106         max: 32.9773
#   float16 min: -65500.0        max: 65500.0
# compress float64 --> float16
# Memory usage : 502.78MB
# Compress Rate: [18.84%]
# ==================================================
# Name: var_143                  Type: float64
#  variable min: 2.8068          max: 22.6916
#   float16 min: -65500.0        max: 65500.0
# compress float64 --> float16
# Memory usage : 500.49MB
# Compress Rate: [19.21%]
# ==================================================
# Name: var_144                  Type: float64
#  variable min: 5.4443          max: 11.8101
#   float16 min: -65500.0        max: 65500.0
# compress float64 --> float16
# Memory usage : 498.20MB
# Compress Rate: [19.58%]
# ==================================================
# Name: var_145                  Type: float64
#  variable min: -8.2734         max: 16.4326
#   float16 min: -65500.0        max: 65500.0
# compress float64 --> float16
# Memory usage : 495.91MB
# Compress Rate: [19.95%]
# ==================================================
# Name: var_146                  Type: float64
#  variable min: 0.4274          max: 20.4373
#   float16 min: -65500.0        max: 65500.0
# compress float64 --> float16
# Memory usage : 493.62MB
# Compress Rate: [20.32%]
# ==================================================
# Name: var_147                  Type: float64
#  variable min: -29.984         max: 22.1494
#   float16 min: -65500.0        max: 65500.0
# compress float64 --> float16
# Memory usage : 491.33MB
# Compress Rate: [20.69%]
# ==================================================
# Name: var_148                  Type: float64
#  variable min: 3.3205          max: 4.8228
#   float16 min: -65500.0        max: 65500.0
# compress float64 --> float16
# Memory usage : 489.04MB
# Compress Rate: [21.06%]
# ==================================================
# Name: var_149                  Type: float64
#  variable min: -41.1683        max: 48.424
#   float16 min: -65500.0        max: 65500.0
# compress float64 --> float16
# Memory usage : 486.76MB
# Compress Rate: [21.43%]
# ==================================================
# Name: var_15                   Type: float64
#  variable min: 13.0769         max: 15.8633
#   float16 min: -65500.0        max: 65500.0
# compress float64 --> float16
# Memory usage : 484.47MB
# Compress Rate: [21.80%]
# ==================================================
# Name: var_150                  Type: float64
#  variable min: 9.242           max: 25.4357
#   float16 min: -65500.0        max: 65500.0
# compress float64 --> float16
# Memory usage : 482.18MB
# Compress Rate: [22.17%]
# ==================================================
# Name: var_151                  Type: float64
#  variable min: -2.9027         max: 22.1488
#   float16 min: -65500.0        max: 65500.0
# compress float64 --> float16
# Memory usage : 479.89MB
# Compress Rate: [22.54%]
# ==================================================
# Name: var_152                  Type: float64
#  variable min: -2.88           max: 18.3846
#   float16 min: -65500.0        max: 65500.0
# compress float64 --> float16
# Memory usage : 477.60MB
# Compress Rate: [22.91%]
# ==================================================
# Name: var_153                  Type: float64
#  variable min: 10.8958         max: 24.0075
#   float16 min: -65500.0        max: 65500.0
# compress float64 --> float16
# Memory usage : 475.31MB
# Compress Rate: [23.28%]
# ==================================================
# Name: var_154                  Type: float64
#  variable min: -8.1966         max: 23.2428
#   float16 min: -65500.0        max: 65500.0
# compress float64 --> float16
# Memory usage : 473.02MB
# Compress Rate: [23.65%]
# ==================================================
# Name: var_155                  Type: float64
#  variable min: -22.41          max: 16.8316
#   float16 min: -65500.0        max: 65500.0
# compress float64 --> float16
# Memory usage : 470.73MB
# Compress Rate: [24.01%]
# ==================================================
# Name: var_156                  Type: float64
#  variable min: 9.9965          max: 16.497
#   float16 min: -65500.0        max: 65500.0
# compress float64 --> float16
# Memory usage : 468.44MB
# Compress Rate: [24.38%]
# ==================================================
# Name: var_157                  Type: float64
#  variable min: -24.9557        max: 13.1897
#   float16 min: -65500.0        max: 65500.0
# compress float64 --> float16
# Memory usage : 466.16MB
# Compress Rate: [24.75%]
# ==================================================
# Name: var_158                  Type: float64
#  variable min: -4.5544         max: 46.1577
#   float16 min: -65500.0        max: 65500.0
# compress float64 --> float16
# Memory usage : 463.87MB
# Compress Rate: [25.12%]
# ==================================================
# Name: var_159                  Type: float64
#  variable min: -4.6416         max: 26.4959
#   float16 min: -65500.0        max: 65500.0
# compress float64 --> float16
# Memory usage : 461.58MB
# Compress Rate: [25.49%]
# ==================================================
# Name: var_16                   Type: float64
#  variable min: 0.3143          max: 17.9506
#   float16 min: -65500.0        max: 65500.0
# compress float64 --> float16
# Memory usage : 459.29MB
# Compress Rate: [25.86%]
# ==================================================
# Name: var_160                  Type: float64
#  variable min: -8.9257         max: 64.2911
#   float16 min: -65500.0        max: 65500.0
# compress float64 --> float16
# Memory usage : 457.00MB
# Compress Rate: [26.23%]
# ==================================================
# Name: var_161                  Type: float64
#  variable min: 4.8526          max: 6.3437
#   float16 min: -65500.0        max: 65500.0
# compress float64 --> float16
# Memory usage : 454.71MB
# Compress Rate: [26.60%]
# ==================================================
# Name: var_162                  Type: float64
#  variable min: 0.1062          max: 10.1942
#   float16 min: -65500.0        max: 65500.0
# compress float64 --> float16
# Memory usage : 452.42MB
# Compress Rate: [26.97%]
# ==================================================
# Name: var_163                  Type: float64
#  variable min: -6.5317         max: 27.5648
#   float16 min: -65500.0        max: 65500.0
# compress float64 --> float16
# Memory usage : 450.13MB
# Compress Rate: [27.34%]
# ==================================================
# Name: var_164                  Type: float64
#  variable min: -21.514         max: 12.1193
#   float16 min: -65500.0        max: 65500.0
# compress float64 --> float16
# Memory usage : 447.85MB
# Compress Rate: [27.71%]
# ==================================================
# Name: var_165                  Type: float64
#  variable min: 3.6673          max: 38.3322
#   float16 min: -65500.0        max: 65500.0
# compress float64 --> float16
# Memory usage : 445.56MB
# Compress Rate: [28.08%]
# ==================================================
# Name: var_166                  Type: float64
#  variable min: 1.8131          max: 4.2204
#   float16 min: -65500.0        max: 65500.0
# compress float64 --> float16
# Memory usage : 443.27MB
# Compress Rate: [28.45%]
# ==================================================
# Name: var_167                  Type: float64
#  variable min: -37.1764        max: 21.2766
#   float16 min: -65500.0        max: 65500.0
# compress float64 --> float16
# Memory usage : 440.98MB
# Compress Rate: [28.82%]
# ==================================================
# Name: var_168                  Type: float64
#  variable min: -5.4057         max: 14.9836
#   float16 min: -65500.0        max: 65500.0
# compress float64 --> float16
# Memory usage : 438.69MB
# Compress Rate: [29.19%]
# ==================================================
# Name: var_169                  Type: float64
#  variable min: 4.2588          max: 7.089
#   float16 min: -65500.0        max: 65500.0
# compress float64 --> float16
# Memory usage : 436.40MB
# Compress Rate: [29.56%]
# ==================================================
# Name: var_17                   Type: float64
#  variable min: -33.3802        max: 19.1509
#   float16 min: -65500.0        max: 65500.0
# compress float64 --> float16
# Memory usage : 434.11MB
# Compress Rate: [29.93%]
# ==================================================
# Name: var_170                  Type: float64
#  variable min: -15.5932        max: 16.8465
#   float16 min: -65500.0        max: 65500.0
# compress float64 --> float16
# Memory usage : 431.82MB
# Compress Rate: [30.30%]
# ==================================================
# Name: var_171                  Type: float64
#  variable min: -22.4793        max: 17.9173
#   float16 min: -65500.0        max: 65500.0
# compress float64 --> float16
# Memory usage : 429.53MB
# Compress Rate: [30.67%]
# ==================================================
# Name: var_172                  Type: float64
#  variable min: -11.7966        max: 53.5919
#   float16 min: -65500.0        max: 65500.0
# compress float64 --> float16
# Memory usage : 427.25MB
# Compress Rate: [31.03%]
# ==================================================
# Name: var_173                  Type: float64
#  variable min: -22.7487        max: 19.2376
#   float16 min: -65500.0        max: 65500.0
# compress float64 --> float16
# Memory usage : 424.96MB
# Compress Rate: [31.40%]
# ==================================================
# Name: var_174                  Type: float64
#  variable min: -2.9953         max: 43.5468
#   float16 min: -65500.0        max: 65500.0
# compress float64 --> float16
# Memory usage : 422.67MB
# Compress Rate: [31.77%]
# ==================================================
# Name: var_175                  Type: float64
#  variable min: 2.9512          max: 20.8548
#   float16 min: -65500.0        max: 65500.0
# compress float64 --> float16
# Memory usage : 420.38MB
# Compress Rate: [32.14%]
# ==================================================
# Name: var_176                  Type: float64
#  variable min: -29.8384        max: 20.2452
#   float16 min: -65500.0        max: 65500.0
# compress float64 --> float16
# Memory usage : 418.09MB
# Compress Rate: [32.51%]
# ==================================================
# Name: var_177                  Type: float64
#  variable min: 4.9521          max: 20.5965
#   float16 min: -65500.0        max: 65500.0
# compress float64 --> float16
# Memory usage : 415.80MB
# Compress Rate: [32.88%]
# ==================================================
# Name: var_178                  Type: float64
#  variable min: -29.2734        max: 29.8413
#   float16 min: -65500.0        max: 65500.0
# compress float64 --> float16
# Memory usage : 413.51MB
# Compress Rate: [33.25%]
# ==================================================
# Name: var_179                  Type: float64
#  variable min: -7.8561         max: 14.0675
#   float16 min: -65500.0        max: 65500.0
# compress float64 --> float16
# Memory usage : 411.22MB
# Compress Rate: [33.62%]
# ==================================================
# Name: var_18                   Type: float64
#  variable min: -11.3242        max: 41.748
#   float16 min: -65500.0        max: 65500.0
# compress float64 --> float16
# Memory usage : 408.94MB
# Compress Rate: [33.99%]
# ==================================================
# Name: var_180                  Type: float64
#  variable min: -22.0374        max: 13.991
#   float16 min: -65500.0        max: 65500.0
# compress float64 --> float16
# Memory usage : 406.65MB
# Compress Rate: [34.36%]
# ==================================================
# Name: var_181                  Type: float64
#  variable min: 5.346           max: 14.3939
#   float16 min: -65500.0        max: 65500.0
# compress float64 --> float16
# Memory usage : 404.36MB
# Compress Rate: [34.73%]
# ==================================================
# Name: var_182                  Type: float64
#  variable min: -28.0928        max: 29.2487
#   float16 min: -65500.0        max: 65500.0
# compress float64 --> float16
# Memory usage : 402.07MB
# Compress Rate: [35.10%]
# ==================================================
# Name: var_183                  Type: float64
#  variable min: -5.4768         max: 25.5685
#   float16 min: -65500.0        max: 65500.0
# compress float64 --> float16
# Memory usage : 399.78MB
# Compress Rate: [35.47%]
# ==================================================
# Name: var_184                  Type: float64
#  variable min: -18.4897        max: 44.3634
#   float16 min: -65500.0        max: 65500.0
# compress float64 --> float16
# Memory usage : 397.49MB
# Compress Rate: [35.84%]
# ==================================================
# Name: var_185                  Type: float64
#  variable min: -22.5833        max: 12.9975
#   float16 min: -65500.0        max: 65500.0
# compress float64 --> float16
# Memory usage : 395.20MB
# Compress Rate: [36.21%]
# ==================================================
# Name: var_186                  Type: float64
#  variable min: -3.0223         max: 21.7392
#   float16 min: -65500.0        max: 65500.0
# compress float64 --> float16
# Memory usage : 392.91MB
# Compress Rate: [36.58%]
# ==================================================
# Name: var_187                  Type: float64
#  variable min: -47.7536        max: 23.5699
#   float16 min: -65500.0        max: 65500.0
# compress float64 --> float16
# Memory usage : 390.62MB
# Compress Rate: [36.95%]
# ==================================================
# Name: var_188                  Type: float64
#  variable min: 4.4123          max: 29.3303
#   float16 min: -65500.0        max: 65500.0
# compress float64 --> float16
# Memory usage : 388.34MB
# Compress Rate: [37.32%]
# ==================================================
# Name: var_189                  Type: float64
#  variable min: -2.5543         max: 4.0341
#   float16 min: -65500.0        max: 65500.0
# compress float64 --> float16
# Memory usage : 386.05MB
# Compress Rate: [37.68%]
# ==================================================
# Name: var_19                   Type: float64
#  variable min: -12.6994        max: 35.4323
#   float16 min: -65500.0        max: 65500.0
# compress float64 --> float16
# Memory usage : 383.76MB
# Compress Rate: [38.05%]
# ==================================================
# Name: var_190                  Type: float64
#  variable min: -14.0933        max: 20.359
#   float16 min: -65500.0        max: 65500.0
# compress float64 --> float16
# Memory usage : 381.47MB
# Compress Rate: [38.42%]
# ==================================================
# Name: var_191                  Type: float64
#  variable min: -2.6917         max: 16.7165
#   float16 min: -65500.0        max: 65500.0
# compress float64 --> float16
# Memory usage : 379.18MB
# Compress Rate: [38.79%]
# ==================================================
# Name: var_192                  Type: float64
#  variable min: -3.8145         max: 8.4024
#   float16 min: -65500.0        max: 65500.0
# compress float64 --> float16
# Memory usage : 376.89MB
# Compress Rate: [39.16%]
# ==================================================
# Name: var_193                  Type: float64
#  variable min: -11.7834        max: 18.2818
#   float16 min: -65500.0        max: 65500.0
# compress float64 --> float16
# Memory usage : 374.60MB
# Compress Rate: [39.53%]
# ==================================================
# Name: var_194                  Type: float64
#  variable min: 8.6944          max: 27.9478
#   float16 min: -65500.0        max: 65500.0
# compress float64 --> float16
# Memory usage : 372.31MB
# Compress Rate: [39.90%]
# ==================================================
# Name: var_195                  Type: float64
#  variable min: -5.261          max: 4.5454
#   float16 min: -65500.0        max: 65500.0
# compress float64 --> float16
# Memory usage : 370.03MB
# Compress Rate: [40.27%]
# ==================================================
# Name: var_196                  Type: float64
#  variable min: -14.2096        max: 18.3215
#   float16 min: -65500.0        max: 65500.0
# compress float64 --> float16
# Memory usage : 367.74MB
# Compress Rate: [40.64%]
# ==================================================
# Name: var_197                  Type: float64
#  variable min: 5.9606          max: 12.2758
#   float16 min: -65500.0        max: 65500.0
# compress float64 --> float16
# Memory usage : 365.45MB
# Compress Rate: [41.01%]
# ==================================================
# Name: var_198                  Type: float64
#  variable min: 6.2993          max: 26.5384
#   float16 min: -65500.0        max: 65500.0
# compress float64 --> float16
# Memory usage : 363.16MB
# Compress Rate: [41.38%]
# ==================================================
# Name: var_199                  Type: float64
#  variable min: -39.4578        max: 28.5007
#   float16 min: -65500.0        max: 65500.0
# compress float64 --> float16
# Memory usage : 360.87MB
# Compress Rate: [41.75%]
# ==================================================
# Name: var_2                    Type: float64
#  variable min: 2.1171          max: 19.353
#   float16 min: -65500.0        max: 65500.0
# compress float64 --> float16
# Memory usage : 358.58MB
# Compress Rate: [42.12%]
# ==================================================
# Name: var_20                   Type: float64
#  variable min: -5.4322         max: 32.0758
#   float16 min: -65500.0        max: 65500.0
# compress float64 --> float16
# Memory usage : 356.29MB
# Compress Rate: [42.49%]
# ==================================================
# Name: var_21                   Type: float64
#  variable min: -10.089         max: 49.0443
#   float16 min: -65500.0        max: 65500.0
# compress float64 --> float16
# Memory usage : 354.00MB
# Compress Rate: [42.86%]
# ==================================================
# Name: var_22                   Type: float64
#  variable min: -5.3225         max: 14.5945
#   float16 min: -65500.0        max: 65500.0
# compress float64 --> float16
# Memory usage : 351.72MB
# Compress Rate: [43.23%]
# ==================================================
# Name: var_23                   Type: float64
#  variable min: 1.2098          max: 5.0246
#   float16 min: -65500.0        max: 65500.0
# compress float64 --> float16
# Memory usage : 349.43MB
# Compress Rate: [43.60%]
# ==================================================
# Name: var_24                   Type: float64
#  variable min: -0.7313         max: 25.446
#   float16 min: -65500.0        max: 65500.0
# compress float64 --> float16
# Memory usage : 347.14MB
# Compress Rate: [43.97%]
# ==================================================
# Name: var_25                   Type: float64
#  variable min: 12.72           max: 14.6546
#   float16 min: -65500.0        max: 65500.0
# compress float64 --> float16
# Memory usage : 344.85MB
# Compress Rate: [44.33%]
# ==================================================
# Name: var_26                   Type: float64
#  variable min: -24.5361        max: 15.6751
#   float16 min: -65500.0        max: 65500.0
# compress float64 --> float16
# Memory usage : 342.56MB
# Compress Rate: [44.70%]
# ==================================================
# Name: var_27                   Type: float64
#  variable min: -6.1668         max: 3.3713
#   float16 min: -65500.0        max: 65500.0
# compress float64 --> float16
# Memory usage : 340.27MB
# Compress Rate: [45.07%]
# ==================================================
# Name: var_28                   Type: float64
#  variable min: 2.0896          max: 8.7874
#   float16 min: -65500.0        max: 65500.0
# compress float64 --> float16
# Memory usage : 337.98MB
# Compress Rate: [45.44%]
# ==================================================
# Name: var_29                   Type: float64
#  variable min: -4.7872         max: 13.1431
#   float16 min: -65500.0        max: 65500.0
# compress float64 --> float16
# Memory usage : 335.69MB
# Compress Rate: [45.81%]
# ==================================================
# Name: var_3                    Type: float64
#  variable min: -0.0402         max: 13.1883
#   float16 min: -65500.0        max: 65500.0
# compress float64 --> float16
# Memory usage : 333.40MB
# Compress Rate: [46.18%]
# ==================================================
# Name: var_30                   Type: float64
#  variable min: -34.7984        max: 15.6515
#   float16 min: -65500.0        max: 65500.0
# compress float64 --> float16
# Memory usage : 331.12MB
# Compress Rate: [46.55%]
# ==================================================
# Name: var_31                   Type: float64
#  variable min: 1.3092          max: 20.1719
#   float16 min: -65500.0        max: 65500.0
# compress float64 --> float16
# Memory usage : 328.83MB
# Compress Rate: [46.92%]
# ==================================================
# Name: var_32                   Type: float64
#  variable min: -8.9861         max: 6.9496
#   float16 min: -65500.0        max: 65500.0
# compress float64 --> float16
# Memory usage : 326.54MB
# Compress Rate: [47.29%]
# ==================================================
# Name: var_33                   Type: float64
#  variable min: 1.5085          max: 29.5466
#   float16 min: -65500.0        max: 65500.0
# compress float64 --> float16
# Memory usage : 324.25MB
# Compress Rate: [47.66%]
# ==================================================
# Name: var_34                   Type: float64
#  variable min: 9.7764          max: 13.2878
#   float16 min: -65500.0        max: 65500.0
# compress float64 --> float16
# Memory usage : 321.96MB
# Compress Rate: [48.03%]
# ==================================================
# Name: var_35                   Type: float64
#  variable min: -16.9238        max: 22.3183
#   float16 min: -65500.0        max: 65500.0
# compress float64 --> float16
# Memory usage : 319.67MB
# Compress Rate: [48.40%]
# ==================================================
# Name: var_36                   Type: float64
#  variable min: -10.4668        max: 14.2456
#   float16 min: -65500.0        max: 65500.0
# compress float64 --> float16
# Memory usage : 317.38MB
# Compress Rate: [48.77%]
# ==================================================
# Name: var_37                   Type: float64
#  variable min: -1.1834         max: 12.0149
#   float16 min: -65500.0        max: 65500.0
# compress float64 --> float16
# Memory usage : 315.09MB
# Compress Rate: [49.14%]
# ==================================================
# Name: var_38                   Type: float64
#  variable min: -6.3371         max: 29.8235
#   float16 min: -65500.0        max: 65500.0
# compress float64 --> float16
# Memory usage : 312.81MB
# Compress Rate: [49.51%]
# ==================================================
# Name: var_39                   Type: float64
#  variable min: -14.5457        max: 15.3223
#   float16 min: -65500.0        max: 65500.0
# compress float64 --> float16
# Memory usage : 310.52MB
# Compress Rate: [49.88%]
# ==================================================
# Name: var_4                    Type: float64
#  variable min: 5.0748          max: 16.6714
#   float16 min: -65500.0        max: 65500.0
# compress float64 --> float16
# Memory usage : 308.23MB
# Compress Rate: [50.25%]
# ==================================================
# Name: var_40                   Type: float64
#  variable min: -35.2117        max: 18.1056
#   float16 min: -65500.0        max: 65500.0
# compress float64 --> float16
# Memory usage : 305.94MB
# Compress Rate: [50.62%]
# ==================================================
# Name: var_41                   Type: float64
#  variable min: -8.5696         max: 26.7255
#   float16 min: -65500.0        max: 65500.0
# compress float64 --> float16
# Memory usage : 303.65MB
# Compress Rate: [50.99%]
# ==================================================
# Name: var_42                   Type: float64
#  variable min: 8.859           max: 13.4696
#   float16 min: -65500.0        max: 65500.0
# compress float64 --> float16
# Memory usage : 301.36MB
# Compress Rate: [51.35%]
# ==================================================
# Name: var_43                   Type: float64
#  variable min: 10.6444         max: 12.5779
#   float16 min: -65500.0        max: 65500.0
# compress float64 --> float16
# Memory usage : 299.07MB
# Compress Rate: [51.72%]
# ==================================================
# Name: var_44                   Type: float64
#  variable min: -9.9396         max: 34.1961
#   float16 min: -65500.0        max: 65500.0
# compress float64 --> float16
# Memory usage : 296.78MB
# Compress Rate: [52.09%]
# ==================================================
# Name: var_45                   Type: float64
#  variable min: -90.2525        max: 62.0844
#   float16 min: -65500.0        max: 65500.0
# compress float64 --> float16
# Memory usage : 294.49MB
# Compress Rate: [52.46%]
# ==================================================
# Name: var_46                   Type: float64
#  variable min: 1.2062          max: 21.2939
#   float16 min: -65500.0        max: 65500.0
# compress float64 --> float16
# Memory usage : 292.21MB
# Compress Rate: [52.83%]
# ==================================================
# Name: var_47                   Type: float64
#  variable min: -47.6862        max: 20.6854
#   float16 min: -65500.0        max: 65500.0
# compress float64 --> float16
# Memory usage : 289.92MB
# Compress Rate: [53.20%]
# ==================================================
# Name: var_48                   Type: float64
#  variable min: -25.1148        max: 54.2738
#   float16 min: -65500.0        max: 65500.0
# compress float64 --> float16
# Memory usage : 287.63MB
# Compress Rate: [53.57%]
# ==================================================
# Name: var_49                   Type: float64
#  variable min: -8.0707         max: 42.0406
#   float16 min: -65500.0        max: 65500.0
# compress float64 --> float16
# Memory usage : 285.34MB
# Compress Rate: [53.94%]
# ==================================================
# Name: var_5                    Type: float64
#  variable min: -32.5626        max: 17.2537
#   float16 min: -65500.0        max: 65500.0
# compress float64 --> float16
# Memory usage : 283.05MB
# Compress Rate: [54.31%]
# ==================================================
# Name: var_50                   Type: float64
#  variable min: 10.1996         max: 15.3172
#   float16 min: -65500.0        max: 65500.0
# compress float64 --> float16
# Memory usage : 280.76MB
# Compress Rate: [54.68%]
# ==================================================
# Name: var_51                   Type: float64
#  variable min: -15.0462        max: 40.689
#   float16 min: -65500.0        max: 65500.0
# compress float64 --> float16
# Memory usage : 278.47MB
# Compress Rate: [55.05%]
# ==================================================
# Name: var_52                   Type: float64
#  variable min: -24.7214        max: 17.2683
#   float16 min: -65500.0        max: 65500.0
# compress float64 --> float16
# Memory usage : 276.18MB
# Compress Rate: [55.42%]
# ==================================================
# Name: var_53                   Type: float64
#  variable min: 3.3449          max: 8.2315
#   float16 min: -65500.0        max: 65500.0
# compress float64 --> float16
# Memory usage : 273.90MB
# Compress Rate: [55.79%]
# ==================================================
# Name: var_54                   Type: float64
#  variable min: -26.7786        max: 29.5903
#   float16 min: -65500.0        max: 65500.0
# compress float64 --> float16
# Memory usage : 271.61MB
# Compress Rate: [56.16%]
# ==================================================
# Name: var_55                   Type: float64
#  variable min: -3.7826         max: 29.8023
#   float16 min: -65500.0        max: 65500.0
# compress float64 --> float16
# Memory usage : 269.32MB
# Compress Rate: [56.53%]
# ==================================================
# Name: var_56                   Type: float64
#  variable min: 2.7618          max: 29.0741
#   float16 min: -65500.0        max: 65500.0
# compress float64 --> float16
# Memory usage : 267.03MB
# Compress Rate: [56.90%]
# ==================================================
# Name: var_57                   Type: float64
#  variable min: 3.4423          max: 9.1793
#   float16 min: -65500.0        max: 65500.0
# compress float64 --> float16
# Memory usage : 264.74MB
# Compress Rate: [57.27%]
# ==================================================
# Name: var_58                   Type: float64
#  variable min: -14.9797        max: 21.438
#   float16 min: -65500.0        max: 65500.0
# compress float64 --> float16
# Memory usage : 262.45MB
# Compress Rate: [57.64%]
# ==================================================
# Name: var_59                   Type: float64
#  variable min: 6.0528          max: 11.9867
#   float16 min: -65500.0        max: 65500.0
# compress float64 --> float16
# Memory usage : 260.16MB
# Compress Rate: [58.00%]
# ==================================================
# Name: var_6                    Type: float64
#  variable min: 2.2164          max: 8.4477
#   float16 min: -65500.0        max: 65500.0
# compress float64 --> float16
# Memory usage : 257.87MB
# Compress Rate: [58.37%]
# ==================================================
# Name: var_60                   Type: float64
#  variable min: -2.1006         max: 25.1955
#   float16 min: -65500.0        max: 65500.0
# compress float64 --> float16
# Memory usage : 255.58MB
# Compress Rate: [58.74%]
# ==================================================
# Name: var_61                   Type: float64
#  variable min: -48.8027        max: 27.1029
#   float16 min: -65500.0        max: 65500.0
# compress float64 --> float16
# Memory usage : 253.30MB
# Compress Rate: [59.11%]
# ==================================================
# Name: var_62                   Type: float64
#  variable min: -6.3899         max: 7.7536
#   float16 min: -65500.0        max: 65500.0
# compress float64 --> float16
# Memory usage : 251.01MB
# Compress Rate: [59.48%]
# ==================================================
# Name: var_63                   Type: float64
#  variable min: -12.6004        max: 11.2317
#   float16 min: -65500.0        max: 65500.0
# compress float64 --> float16
# Memory usage : 248.72MB
# Compress Rate: [59.85%]
# ==================================================
# Name: var_64                   Type: float64
#  variable min: 1.4867          max: 11.1537
#   float16 min: -65500.0        max: 65500.0
# compress float64 --> float16
# Memory usage : 246.43MB
# Compress Rate: [60.22%]
# ==================================================
# Name: var_65                   Type: float64
#  variable min: -15.2429        max: 15.7313
#   float16 min: -65500.0        max: 65500.0
# compress float64 --> float16
# Memory usage : 244.14MB
# Compress Rate: [60.59%]
# ==================================================
# Name: var_66                   Type: float64
#  variable min: 1.3368          max: 9.8972
#   float16 min: -65500.0        max: 65500.0
# compress float64 --> float16
# Memory usage : 241.85MB
# Compress Rate: [60.96%]
# ==================================================
# Name: var_67                   Type: float64
#  variable min: -19.5443        max: 41.5147
#   float16 min: -65500.0        max: 65500.0
# compress float64 --> float16
# Memory usage : 239.56MB
# Compress Rate: [61.33%]
# ==================================================
# Name: var_68                   Type: float64
#  variable min: 4.9938          max: 5.0469
#   float16 min: -65500.0        max: 65500.0
# compress float64 --> float16
# Memory usage : 237.27MB
# Compress Rate: [61.70%]
# ==================================================
# Name: var_69                   Type: float64
#  variable min: -16.3094        max: 8.5473
#   float16 min: -65500.0        max: 65500.0
# compress float64 --> float16
# Memory usage : 234.99MB
# Compress Rate: [62.07%]
# ==================================================
# Name: var_7                    Type: float64
#  variable min: 5.3497          max: 28.2928
#   float16 min: -65500.0        max: 65500.0
# compress float64 --> float16
# Memory usage : 232.70MB
# Compress Rate: [62.44%]
# ==================================================
# Name: var_70                   Type: float64
#  variable min: -17.0275        max: 64.4644
#   float16 min: -65500.0        max: 65500.0
# compress float64 --> float16
# Memory usage : 230.41MB
# Compress Rate: [62.81%]
# ==================================================
# Name: var_71                   Type: float64
#  variable min: -0.224          max: 1.5719
#   float16 min: -65500.0        max: 65500.0
# compress float64 --> float16
# Memory usage : 228.12MB
# Compress Rate: [63.18%]
# ==================================================
# Name: var_72                   Type: float64
#  variable min: -12.7283        max: 15.6133
#   float16 min: -65500.0        max: 65500.0
# compress float64 --> float16
# Memory usage : 225.83MB
# Compress Rate: [63.55%]
# ==================================================
# Name: var_73                   Type: float64
#  variable min: -1.6658         max: 44.5361
#   float16 min: -65500.0        max: 65500.0
# compress float64 --> float16
# Memory usage : 223.54MB
# Compress Rate: [63.92%]
# ==================================================
# Name: var_74                   Type: float64
#  variable min: -37.347         max: 84.6841
#   float16 min: -65500.0        max: 65500.0
# compress float64 --> float16
# Memory usage : 221.25MB
# Compress Rate: [64.29%]
# ==================================================
# Name: var_75                   Type: float64
#  variable min: -1.2936         max: 37.9478
#   float16 min: -65500.0        max: 65500.0
# compress float64 --> float16
# Memory usage : 218.96MB
# Compress Rate: [64.66%]
# ==================================================
# Name: var_76                   Type: float64
#  variable min: -21.6333        max: 34.4352
#   float16 min: -65500.0        max: 65500.0
# compress float64 --> float16
# Memory usage : 216.67MB
# Compress Rate: [65.02%]
# ==================================================
# Name: var_77                   Type: float64
#  variable min: 7.4257          max: 30.9678
#   float16 min: -65500.0        max: 65500.0
# compress float64 --> float16
# Memory usage : 214.39MB
# Compress Rate: [65.39%]
# ==================================================
# Name: var_78                   Type: float64
#  variable min: -1.8183         max: 11.5712
#   float16 min: -65500.0        max: 65500.0
# compress float64 --> float16
# Memory usage : 212.10MB
# Compress Rate: [65.76%]
# ==================================================
# Name: var_79                   Type: float64
#  variable min: 10.4454         max: 18.2256
#   float16 min: -65500.0        max: 65500.0
# compress float64 --> float16
# Memory usage : 209.81MB
# Compress Rate: [66.13%]
# ==================================================
# Name: var_8                    Type: float64
#  variable min: -10.5055        max: 10.1513
#   float16 min: -65500.0        max: 65500.0
# compress float64 --> float16
# Memory usage : 207.52MB
# Compress Rate: [66.50%]
# ==================================================
# Name: var_80                   Type: float64
#  variable min: -18.0422        max: 30.4769
#   float16 min: -65500.0        max: 65500.0
# compress float64 --> float16
# Memory usage : 205.23MB
# Compress Rate: [66.87%]
# ==================================================
# Name: var_81                   Type: float64
#  variable min: 7.5865          max: 23.4373
#   float16 min: -65500.0        max: 65500.0
# compress float64 --> float16
# Memory usage : 202.94MB
# Compress Rate: [67.24%]
# ==================================================
# Name: var_82                   Type: float64
#  variable min: -30.3146        max: 21.8934
#   float16 min: -65500.0        max: 65500.0
# compress float64 --> float16
# Memory usage : 200.65MB
# Compress Rate: [67.61%]
# ==================================================
# Name: var_83                   Type: float64
#  variable min: -24.7091        max: 27.7143
#   float16 min: -65500.0        max: 65500.0
# compress float64 --> float16
# Memory usage : 198.36MB
# Compress Rate: [67.98%]
# ==================================================
# Name: var_84                   Type: float64
#  variable min: -24.5639        max: 17.7424
#   float16 min: -65500.0        max: 65500.0
# compress float64 --> float16
# Memory usage : 196.08MB
# Compress Rate: [68.35%]
# ==================================================
# Name: var_85                   Type: float64
#  variable min: 7.023           max: 32.9011
#   float16 min: -65500.0        max: 65500.0
# compress float64 --> float16
# Memory usage : 193.79MB
# Compress Rate: [68.72%]
# ==================================================
# Name: var_86                   Type: float64
#  variable min: -19.2722        max: 34.5637
#   float16 min: -65500.0        max: 65500.0
# compress float64 --> float16
# Memory usage : 191.50MB
# Compress Rate: [69.09%]
# ==================================================
# Name: var_87                   Type: float64
#  variable min: -8.4816         max: 33.3541
#   float16 min: -65500.0        max: 65500.0
# compress float64 --> float16
# Memory usage : 189.21MB
# Compress Rate: [69.46%]
# ==================================================
# Name: var_88                   Type: float64
#  variable min: 1.3502          max: 17.4594
#   float16 min: -65500.0        max: 65500.0
# compress float64 --> float16
# Memory usage : 186.92MB
# Compress Rate: [69.83%]
# ==================================================
# Name: var_89                   Type: float64
#  variable min: -9.6014         max: 16.0321
#   float16 min: -65500.0        max: 65500.0
# compress float64 --> float16
# Memory usage : 184.63MB
# Compress Rate: [70.20%]
# ==================================================
# Name: var_9                    Type: float64
#  variable min: 3.9705          max: 11.1506
#   float16 min: -65500.0        max: 65500.0
# compress float64 --> float16
# Memory usage : 182.34MB
# Compress Rate: [70.57%]
# ==================================================
# Name: var_90                   Type: float64
#  variable min: -61.718         max: 27.2713
#   float16 min: -65500.0        max: 65500.0
# compress float64 --> float16
# Memory usage : 180.05MB
# Compress Rate: [70.94%]
# ==================================================
# Name: var_91                   Type: float64
#  variable min: 6.5218          max: 7.5014
#   float16 min: -65500.0        max: 65500.0
# compress float64 --> float16
# Memory usage : 177.76MB
# Compress Rate: [71.31%]
# ==================================================
# Name: var_92                   Type: float64
#  variable min: -1.0185         max: 28.4435
#   float16 min: -65500.0        max: 65500.0
# compress float64 --> float16
# Memory usage : 175.48MB
# Compress Rate: [71.67%]
# ==================================================
# Name: var_93                   Type: float64
#  variable min: 8.4916          max: 12.5343
#   float16 min: -65500.0        max: 65500.0
# compress float64 --> float16
# Memory usage : 173.19MB
# Compress Rate: [72.04%]
# ==================================================
# Name: var_94                   Type: float64
#  variable min: 2.8171          max: 18.975
#   float16 min: -65500.0        max: 65500.0
# compress float64 --> float16
# Memory usage : 170.90MB
# Compress Rate: [72.41%]
# ==================================================
# Name: var_95                   Type: float64
#  variable min: -2.4324         max: 1.9262
#   float16 min: -65500.0        max: 65500.0
# compress float64 --> float16
# Memory usage : 168.61MB
# Compress Rate: [72.78%]
# ==================================================
# Name: var_96                   Type: float64
#  variable min: -12.1584        max: 42.4257
#   float16 min: -65500.0        max: 65500.0
# compress float64 --> float16
# Memory usage : 166.32MB
# Compress Rate: [73.15%]
# ==================================================
# Name: var_97                   Type: float64
#  variable min: -24.5027        max: 58.2879
#   float16 min: -65500.0        max: 65500.0
# compress float64 --> float16
# Memory usage : 164.03MB
# Compress Rate: [73.52%]
# ==================================================
# Name: var_98                   Type: float64
#  variable min: -0.6035         max: 4.5728
#   float16 min: -65500.0        max: 65500.0
# compress float64 --> float16
# Memory usage : 161.74MB
# Compress Rate: [73.89%]
# ==================================================
# Name: var_99                   Type: float64
#  variable min: -7.364          max: 5.0764
#   float16 min: -65500.0        max: 65500.0
# compress float64 --> float16
# Memory usage : 159.45MB
# Compress Rate: [74.26%]
# ==================================================
#
# Memory usage : 159.45MB
# Compress Rate: [74.26%]
